# %%
import os
import pandas as pd
import numpy as np
import glob

# %%
PYSERINI_FOLDER="/media/eduseiti/bigdata01/unicamp/ia368v_dd/pyserini"

# %%
CLUEWEB22_FOLDER="/media/eduseiti/bigdata01/unicamp/ia368v_dd/trabalho_final/clueweb22-pt_10M_sample_fixed/"

# %%
CLUEWEB22_1M_PT_BR_DATASET="clueweb22-pt_colbertx_cleaned_massiveweb_1M_sample.tsv"

BM25_OUTPUT_FOLDER="/media/eduseiti/bigdata01/unicamp/ia368v_dd/unicamp_IR/retrievals/bm25_massiveweb"
BM25_INDEX="/media/eduseiti/bigdata01/unicamp/ia368v_dd/unicamp_IR/retrievals/bm25_massiveweb/index"
BM25_RUNS="/media/eduseiti/bigdata01/unicamp/ia368v_dd/unicamp_IR/retrievals/bm25_massiveweb/runs"

# %%
QUERIES_FOLDER="/media/eduseiti/bigdata01/unicamp/ia368v_dd/unicamp_IR/tests"
QUERIES_PART_01="queries_validation.tsv"
QUERIES_PART_02="validation_queries_mirelle.tsv"
SAMPLED_QUERIES_PASSAGES="07_retrievers_docs_000_009_sampled_50_queries.tsv"

# %%
os.chdir(PYSERINI_FOLDER)

# %%
os.environ["ANSERINI_CLASSPATH"]="/media/eduseiti/bigdata01/unicamp/ia368v_dd/anserini/target"

# %% [markdown]
# ### Converting the dataset to pyserini's format

# %%
dataset_df = pd.read_csv(os.path.join(CLUEWEB22_FOLDER, CLUEWEB22_1M_PT_BR_DATASET), 
                         sep="\t", header=None, names=['passage_id', 'passage', 'n_tokens', 'massiveweb_filters'])

# %%
dataset_df
# Out:
#         passage_id                                            passage  \
# 0                5  Se você precisar de ajuda, visite o website na...
# 1                6  Qual a parada final de Sintra para Cascais ôni...
# 2                7  O Casino Estoril fica localizado no Estoril, a...
# 3                8  Sintra para Lisboa Sintra para Óbidos Leiria P...
# 4               11  Iniciar a digitalização Iniciar a digitalizaçã...
# ...            ...                                                ...
# 999995     9999960  Pararam totalmente suas vidas, reagiram parand...
# 999996     9999967  Recicla Eletro - Coleta Gratuita de Lixo Eletr...
# 999997     9999981  É importante falar de liberdade ao falar de Ro...
# 999998     9999989  Os artigos 2º e artigos 84 a 86 da Lei nº 13.1...
# 999999     9999996  4) a citação da curatelada para comparecer em ...
#
#         n_tokens  massiveweb_filters
# 0            361                   0
# 1            382                   0
# 2            255                   0
# 3            283                   0
# 4            293                   0
# ...          ...                 ...
# 999995       337                   0
# 999996       386                   0
# 999997       261                   0
# 999998       375                   0
# 999999       387                   0
#
# [1000000 rows x 4 columns]

# %%
output_filename = "{}_two_colunms.tsv".format(os.path.splitext(CLUEWEB22_1M_PT_BR_DATASET)[0])

# %%
two_columns_file = os.path.join(CLUEWEB22_FOLDER, output_filename)

# %%
dataset_df[dataset_df.columns[:2]].to_csv(two_columns_file, sep='\t', header=None, index=False)

# %%
# !python3 tools/scripts/msmarco/convert_collection_to_jsonl.py \
    --collection-path {two_columns_file} \
    --output-folder {BM25_OUTPUT_FOLDER}
# Out:
# Converting collection...
# Converted 0 docs, writing into file 1
# Converted 100,000 docs, writing into file 1
# Converted 200,000 docs, writing into file 1
# Converted 300,000 docs, writing into file 1
# Converted 400,000 docs, writing into file 1
# Converted 500,000 docs, writing into file 1
# Converted 600,000 docs, writing into file 1
# Converted 700,000 docs, writing into file 1
# Converted 800,000 docs, writing into file 1
# Converted 900,000 docs, writing into file 1
# Done!

# %% [markdown]
# ## Indexação do dataset

# %%
# !python3 -m pyserini.index.lucene \
    --collection JsonCollection \
    --input {BM25_OUTPUT_FOLDER} \
    --index {BM25_INDEX} \
    --language pt \
    --generator DefaultLuceneDocumentGenerator \
    --threads 9 \
    --storePositions --storeDocvectors --storeRaw
# Out:
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# 2024-01-02 20:57:48,472 INFO  [main] index.IndexCollection (IndexCollection.java:393) - Setting log level to INFO
# 2024-01-02 20:57:48,473 INFO  [main] index.IndexCollection (IndexCollection.java:396) - Starting indexer...
# 2024-01-02 20:57:48,473 INFO  [main] index.IndexCollection (IndexCollection.java:397) - ============ Loading Parameters ============
# 2024-01-02 20:57:48,473 INFO  [main] index.IndexCollection (IndexCollection.java:398) - DocumentCollection path: /media/eduseiti/bigdata01/unicamp/ia368v_dd/unicamp_IR/retrievals/bm25_massiveweb
# 2024-01-02 20:57:48,473 INFO  [main] index.IndexCollection (IndexCollection.java:399) - CollectionClass: JsonCollection
# 2024-01-02 20:57:48,474 INFO  [main] index.IndexCollection (IndexCollection.java:400) - Generator: DefaultLuceneDocumentGenerator
# 2024-01-02 20:57:48,474 INFO  [main] index.IndexCollection (IndexCollection.java:401) - Threads: 9
# 2024-01-02 20:57:48,474 INFO  [main] index.IndexCollection (IndexCollection.java:402) - Language: pt
# 2024-01-02 20:57:48,474 INFO  [main] index.IndexCollection (IndexCollection.java:403) - Stemmer: porter
# 2024-01-02 20:57:48,474 INFO  [main] index.IndexCollection (IndexCollection.java:404) - Keep stopwords? false
# 2024-01-02 20:57:48,474 INFO  [main] index.IndexCollection (IndexCollection.java:405) - Stopwords: null
# 2024-01-02 20:57:48,475 INFO  [main] index.IndexCollection (IndexCollection.java:406) - Store positions? true
# 2024-01-02 20:57:48,475 INFO  [main] index.IndexCollection (IndexCollection.java:407) - Store docvectors? true
# 2024-01-02 20:57:48,475 INFO  [main] index.IndexCollection (IndexCollection.java:408) - Store document "contents" field? false
# 2024-01-02 20:57:48,475 INFO  [main] index.IndexCollection (IndexCollection.java:409) - Store document "raw" field? true
# 2024-01-02 20:57:48,475 INFO  [main] index.IndexCollection (IndexCollection.java:410) - Additional fields to index: []
# 2024-01-02 20:57:48,475 INFO  [main] index.IndexCollection (IndexCollection.java:411) - Optimize (merge segments)? false
# 2024-01-02 20:57:48,476 INFO  [main] index.IndexCollection (IndexCollection.java:412) - Whitelist: null
# 2024-01-02 20:57:48,476 INFO  [main] index.IndexCollection (IndexCollection.java:413) - Pretokenized?: false
# 2024-01-02 20:57:48,476 INFO  [main] index.IndexCollection (IndexCollection.java:414) - Index path: /media/eduseiti/bigdata01/unicamp/ia368v_dd/unicamp_IR/retrievals/bm25_massiveweb/index
# 2024-01-02 20:57:48,477 INFO  [main] index.IndexCollection (IndexCollection.java:452) - ============ Indexing Collection ============
# 2024-01-02 20:57:48,701 INFO  [main] index.IndexCollection (IndexCollection.java:567) - Thread pool with 9 threads initialized.
# 2024-01-02 20:57:48,701 INFO  [main] index.IndexCollection (IndexCollection.java:569) - Initializing collection in /media/eduseiti/bigdata01/unicamp/ia368v_dd/unicamp_IR/retrievals/bm25_massiveweb
# 2024-01-02 20:57:48,705 INFO  [main] index.IndexCollection (IndexCollection.java:578) - 1 file found
# 2024-01-02 20:57:48,705 INFO  [main] index.IndexCollection (IndexCollection.java:579) - Starting to index...
# 2024-01-02 20:58:48,706 INFO  [main] index.IndexCollection (IndexCollection.java:591) - 410.000 documents indexed
# 2024-01-02 20:59:48,707 INFO  [main] index.IndexCollection (IndexCollection.java:591) - 800.000 documents indexed
# 2024-01-02 21:00:17,405 DEBUG [pool-2-thread-1] index.IndexCollection$LocalIndexerThread (IndexCollection.java:358) - bm25_massiveweb/docs00.json: 1000000 docs added.
# 2024-01-02 21:00:33,387 INFO  [main] index.IndexCollection (IndexCollection.java:635) - Indexing Complete! 1.000.000 documents indexed
# 2024-01-02 21:00:33,387 INFO  [main] index.IndexCollection (IndexCollection.java:636) - ============ Final Counter Values ============
# 2024-01-02 21:00:33,387 INFO  [main] index.IndexCollection (IndexCollection.java:637) - indexed:        1.000.000
# 2024-01-02 21:00:33,387 INFO  [main] index.IndexCollection (IndexCollection.java:638) - unindexable:            0
# 2024-01-02 21:00:33,387 INFO  [main] index.IndexCollection (IndexCollection.java:639) - empty:                  0
# 2024-01-02 21:00:33,387 INFO  [main] index.IndexCollection (IndexCollection.java:640) - skipped:                0
# 2024-01-02 21:00:33,387 INFO  [main] index.IndexCollection (IndexCollection.java:641) - errors:                 0
# 2024-01-02 21:00:33,390 INFO  [main] index.IndexCollection (IndexCollection.java:644) - Total 1.000.000 documents indexed in 00:02:44

# %% [markdown]
# ### Perform search on the 50 sampled queries

# %%
from pyserini.search import LuceneSearcher, SimpleSearcher
from pyserini.analysis import get_lucene_analyzer

# %%
from datetime import datetime

# %% [markdown]
# #### First, consolidate all the queries

# %%
sampled_df = pd.read_csv(os.path.join(QUERIES_FOLDER, "sampled_queries_no_header.tsv"), sep='\t', names=['query_id', 'query'])

# %% [markdown]
# #### Perform the search

# %%
analyzer = get_lucene_analyzer("pt")
searcher = LuceneSearcher(BM25_INDEX)
searcher.set_analyzer(analyzer)

# %%
sampled_df.iloc[0]['query']
# Out:
# 'Qual a maior característica da fauna brasileira?'

# %%
hits = searcher.search(sampled_df.iloc[1]['query'], k=1000)

# %%
hits
# Out:
# [<io.anserini.search.SimpleSearcher$Result at 0x7fb4b65c9cb0 jclass=io/anserini/search/SimpleSearcher$Result jself=<LocalRef obj=0x563e1833be30 at 0x7fb610951450>>,
#  <io.anserini.search.SimpleSearcher$Result at 0x7fb6251dad40 jclass=io/anserini/search/SimpleSearcher$Result jself=<LocalRef obj=0x563e1833be38 at 0x7fb4b6502b30>>,
#  <io.anserini.search.SimpleSearcher$Result at 0x7fb4b65ca610 jclass=io/anserini/search/SimpleSearcher$Result jself=<LocalRef obj=0x563e1833be40 at 0x7fb4b65025b0>>,
#  <io.anserini.search.SimpleSearcher$Result at 0x7fb4b65cb380 jclass=io/anserini/search/SimpleSearcher$Result jself=<LocalRef obj=0x563e1833be48 at 0x7fb4b6502c10>>,
#  <io.anserini.search.SimpleSearcher$Result at 0x7fb4b65cb330 jclass=io/anserini/search/SimpleSearcher$Result jself=<LocalRef obj=0x563e1833be50 at 0x7fb4b6501c30>>,
#  <io.anserini.search.SimpleSearcher$Result at 0x7fb4b65cb290 jclass=io/anserini/search/SimpleSearcher$Result jself=<LocalRef obj=0x563e1833be60 at 0x7fb4ceccc970>>,
#  <io.anserini.search.SimpleSearcher$Result at 0x7fb4b65cb0b0 jclass=io/anserini/search/SimpleSearcher$Result jself=<LocalRef obj=0x563e1833be70 at 0x7fb4b65019b0>>,
#  <io.anserini.search.SimpleSearcher$Result at 0x7fb4b65c9b20 jclass=io/anserini/search/SimpleSearcher$Result jself=<LocalRef obj=0x563e1833be78 at 0x7fb4b6501b10>>,
#  <io.anserini.search.SimpleSearcher$Result at 0x7fb4b65ca200 jclass=io/anserini/search/SimpleSearcher$Result jself=<LocalRef obj=0x563e1833be80 at 0x7fb4b6502ef0>>,
#  <io.anserini.search.SimpleSearcher$Result at 0x7fb4b65cb470 jclass=io/anserini/search/SimpleSearcher$Result jself=<LocalRef obj=0x563e1
#   "contents" : "Guiana Inglesa, como é a vida? Como vivem os brasileiros que moram lá? – O mundo numa mochila Guiana Inglesa, como é a vida? Como vivem os brasileiros que moram lá? Publicado em abril 22, 2015 Das três guianas, o único país que efetivamente ficou com o nome de Guiana foi a antiga Guiana Inglesa. Se o Suriname foi tudo o que eu não imaginava, a Guiana Inglesa terminou por ser tudo o que eu imaginava. Ou pior. Não há nada que deixe um surinamês mais feliz do que comentar como o Suriname parece um país ano-luz na frente da Guiana Inglesa e não há nada que deixe um guiano mais chateado do que comentar como o Suriname parece um país ano-luz à frente da Guiana."
# }

# %% [markdown]
# #### Perform bulk search

# %%
topics_path = os.path.join(QUERIES_FOLDER, "sampled_queries_no_header.tsv")

execution_timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
pyserini_runfile = os.path.join(BM25_RUNS, "run_{}.txt".format(execution_timestamp))

# %%
# !python3 -m pyserini.search.lucene \
    --language "pt" \
    --index {BM25_INDEX} \
    --topics {topics_path} \
    --output {pyserini_runfile} \
    --output-format trec \
    --hits 1000 \
    --bm25 --k1 0.82 --b 0.68 \
    --threads 8
# Out:
# Setting BM25 parameters: k1=0.82, b=0.68
# Running /media/eduseiti/bigdata01/unicamp/ia368v_dd/unicamp_IR/tests/sampled_queries_no_header.tsv topics, saving to /media/eduseiti/bigdata01/unicamp/ia368v_dd/unicamp_IR/retrievals/bm25_massiveweb/runs/run_20240102_210158.txt...
# 100%|███████████████████████████████████████████| 50/50 [00:03<00:00, 16.49it/s]

# %% [markdown]
# ### Convert document ID to original clueweb22 ID

# %%
run_file = pd.read_csv(pyserini_runfile, sep=' ', header=None, names=['query_id', 'Q0', 'colbertx_id', 'position', 'score', 'comment'])

# %%
run_file
# Out:
#        query_id  Q0  colbertx_id  position      score   comment
# 0             1  Q0       264425         1  11.670300  Anserini
# 1             1  Q0      3718313         2  10.147600  Anserini
# 2             1  Q0      4178525         3   9.934500  Anserini
# 3             1  Q0      3299432         4   9.916500  Anserini
# 4             1  Q0      2605802         5   9.785500  Anserini
# ...         ...  ..          ...       ...        ...       ...
# 49995       199  Q0      1363114       996   4.064500  Anserini
# 49996       199  Q0      5680245       997   4.064499  Anserini
# 49997       199  Q0      6674135       998   4.064498  Anserini
# 49998       199  Q0      6887827       999   4.064497  Anserini
# 49999       199  Q0      7803143      1000   4.064496  Anserini
#
# [50000 rows x 6 columns]

# %%
id_conversion_df = pd.read_csv(os.path.join(CLUEWEB22_FOLDER, "clueweb22-pt_colbertx_to_clueweb_id.tsv"), sep="\t", names=['colbertx_id', 'clueweb_id'])

# %%
run_file_converted_id = run_file.merge(id_conversion_df).sort_values(['query_id', 'position'])

# %%
converted_run_filename = os.path.join(BM25_RUNS, "{}_converted.txt".format(os.path.splitext(os.path.basename(pyserini_runfile))[0]))

# %%
converted_run_filename
# Out:
# '/media/eduseiti/bigdata01/unicamp/ia368v_dd/unicamp_IR/retrievals/bm25_massiveweb/runs/run_20240102_210158_converted.txt'

# %%
run_file_converted_id[['query_id', 'Q0', 'clueweb_id', 'position', 'score', 'comment']].to_csv(converted_run_filename, sep=" ", header=None, index=False)

# %% [markdown]
# ### Evaluate the result

# %%
qrels_filename = os.path.join(QUERIES_FOLDER, "evaluation_08_retrievers_000_009_sampled_50_queries_gpt-4-1106-preview_20231227_qrel.txt")

# %%
result = !/media/eduseiti/bigdata01/unicamp/ia368v_dd/pyserini/tools/eval/trec_eval.9.0.4/trec_eval -c -mndcg_cut.10 \
    {qrels_filename} {converted_run_filename}

# %%
result
# Out:
# ['ndcg_cut_10           \tall\t0.1657']

# %% [markdown]
# ### Check GPT-4 execution log to verify how many passages have been annotated

# %%
import pickle

# %%
with open(os.path.join(QUERIES_FOLDER, "execution_with_reverse_rev_2.1_sampled_50_queries_gpt-4-1106-preview_20231227.pkl"), "rb") as input_file:
    logs = pickle.load(input_file)

# %%
logs.keys()
# Out:
# dict_keys(['args', 'evaluation_cache', 'reverse_mapping'])

# %%
run_file_converted_id = run_file_converted_id.merge(sampled_df)

# %%
top_10_df = run_file_converted_id.groupby('query_id').head(10)

# %%
already_analized = 0

for i, row in top_10_df.iterrows():
    if (row['query'] + "_" + row['clueweb_id']) in logs['evaluation_cache']:
        print("Already analized...")

        already_analized += 1
# Out:
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...

# %%
already_analized
# Out:
# 128

# %%
top_10_df.shape
# Out:
# (500, 8)

# %%
top_10_df
# Out:
#        query_id  Q0  colbertx_id  position    score   comment  \
# 0             1  Q0       264425         1  11.6703  Anserini
# 1             1  Q0      3718313         2  10.1476  Anserini
# 2             1  Q0      4178525         3   9.9345  Anserini
# 3             1  Q0      3299432         4   9.9165  Anserini
# 4             1  Q0      2605802         5   9.7855  Anserini
# ...         ...  ..          ...       ...      ...       ...
# 49005       199  Q0      2320343         6  11.0092  Anserini
# 49006       199  Q0      9715417         7  10.6608  Anserini
# 49007       199  Q0      5978727         8  10.0990  Anserini
# 49008       199  Q0       410165         9  10.0778  Anserini
# 49009       199  Q0      4107348        10  10.0431  Anserini
#
#                         clueweb_id  \
# 0      clueweb22-pt0000-05-02747_0
# 1      clueweb22-pt0000-78-09747_0
# 2      clueweb22-pt0000-87-14633_2
# 3      clueweb22-pt0000-69-05954_7
# 4      clueweb22-pt0000-55-02859_0
# ...                            ...
# 49005  clueweb22-pt0000-48-17441_2
# 49006  clueweb22-pt0002-04-01418_0
# 49007  clueweb22-pt0001-24-17228_0
# 49008  clueweb22-pt0000-08-07683_2
# 49009  clueweb22-pt0000-86-08729_0
#
#                                                    query
# 0       Qual a maior característica da fauna brasileira?
# 1       Qual a maior característica da fauna brasileira?
# 2       Qual a maior característica da fauna brasileira?
# 3       Qual a maior característica da fauna brasileira?
# 4       Qual a maior característica da fauna brasileira?
# ...                                                  ...
# 49005  Quais foram os principais artistas do Impressi...
# 49006  Quais foram os principais artistas do Impressi...
# 49007  Quais foram os principais artistas do Impressi...
# 49008  Quais foram os principais artistas do Impressi...
# 49009  Quais foram os principais artistas do Impressi...
#
# [500 rows x 8 columns]

# %% [markdown]
# ### Add passage text to run GPT-4 evaluation

# %%
dataset_df
# Out:
#         passage_id                                            passage  \
# 0                5  Se você precisar de ajuda, visite o website na...
# 1                6  Qual a parada final de Sintra para Cascais ôni...
# 2                7  O Casino Estoril fica localizado no Estoril, a...
# 3                8  Sintra para Lisboa Sintra para Óbidos Leiria P...
# 4               11  Iniciar a digitalização Iniciar a digitalizaçã...
# ...            ...                                                ...
# 999995     9999960  Pararam totalmente suas vidas, reagiram parand...
# 999996     9999967  Recicla Eletro - Coleta Gratuita de Lixo Eletr...
# 999997     9999981  É importante falar de liberdade ao falar de Ro...
# 999998     9999989  Os artigos 2º e artigos 84 a 86 da Lei nº 13.1...
# 999999     9999996  4) a citação da curatelada para comparecer em ...
#
#         n_tokens  massiveweb_filters
# 0            361                   0
# 1            382                   0
# 2            255                   0
# 3            283                   0
# 4            293                   0
# ...          ...                 ...
# 999995       337                   0
# 999996       386                   0
# 999997       261                   0
# 999998       375                   0
# 999999       387                   0
#
# [1000000 rows x 4 columns]

# %%
dataset_with_clueweb_id_df = dataset_df.merge(id_conversion_df, left_on="passage_id", right_on="colbertx_id")

# %%
dataset_with_clueweb_id_df
# Out:
#         passage_id                                            passage  \
# 0                5  Se você precisar de ajuda, visite o website na...
# 1                6  Qual a parada final de Sintra para Cascais ôni...
# 2                7  O Casino Estoril fica localizado no Estoril, a...
# 3                8  Sintra para Lisboa Sintra para Óbidos Leiria P...
# 4               11  Iniciar a digitalização Iniciar a digitalizaçã...
# ...            ...                                                ...
# 999995     9999960  Pararam totalmente suas vidas, reagiram parand...
# 999996     9999967  Recicla Eletro - Coleta Gratuita de Lixo Eletr...
# 999997     9999981  É importante falar de liberdade ao falar de Ro...
# 999998     9999989  Os artigos 2º e artigos 84 a 86 da Lei nº 13.1...
# 999999     9999996  4) a citação da curatelada para comparecer em ...
#
#         n_tokens  massiveweb_filters  colbertx_id  \
# 0            361                   0            5
# 1            382                   0            6
# 2            255                   0            7
# 3            283                   0            8
# 4            293                   0           11
# ...          ...                 ...          ...
# 999995       337                   0      9999960
# 999996       386                   0      9999967
# 999997       261                   0      9999981
# 999998       375                   0      9999989
# 999999       387                   0      9999996
#
#                           clueweb_id
# 0        clueweb22-pt0000-00-00003_1
# 1        clueweb22-pt0000-00-00003_2
# 2        clueweb22-pt0000-00-00003_3
# 3        clueweb22-pt0000-00-00003_5
# 4        clueweb22-pt0000-00-00008_0
# ...                              ...
# 999995   clueweb22-pt0002-45-01752_2
# 999996   clueweb22-pt0002-45-01757_0
# 999997   clueweb22-pt0002-45-01760_4
# 999998   clueweb22-pt0002-45-01762_5
# 999999  clueweb22-pt0002-45-01762_17
#
# [1000000 rows x 6 columns]

# %%
dataset_with_clueweb_id_df[['clueweb_id', 'passage', 'n_tokens', 'colbertx_id']].to_csv(os.path.join(CLUEWEB22_FOLDER, "clueweb22-pt_cleaned_massiveweb_1M_sample.tsv"), 
                                                                                        sep="\t", header=None, index=False)

# %%
dataset_with_clueweb_id_df[['clueweb_id', 'passage']].to_csv(os.path.join(CLUEWEB22_FOLDER, "clueweb22-pt_cleaned_massiveweb_1M_sample_two_columns.tsv"), 
                                                             sep="\t", header=None, index=False)

# %%
top_10_df = top_10_df.merge(dataset_with_clueweb_id_df[['clueweb_id', 'passage']]).sort_values(['query_id', 'position'])

# %%
top_10_df
# Out:
#      query_id  Q0  colbertx_id  position    score   comment  \
# 0           1  Q0       264425         1  11.6703  Anserini
# 1           1  Q0      3718313         2  10.1476  Anserini
# 2           1  Q0      4178525         3   9.9345  Anserini
# 3           1  Q0      3299432         4   9.9165  Anserini
# 4           1  Q0      2605802         5   9.7855  Anserini
# ..        ...  ..          ...       ...      ...       ...
# 495       199  Q0      2320343         6  11.0092  Anserini
# 496       199  Q0      9715417         7  10.6608  Anserini
# 497       199  Q0      5978727         8  10.0990  Anserini
# 498       199  Q0       410165         9  10.0778  Anserini
# 499       199  Q0      4107348        10  10.0431  Anserini
#
#                       clueweb_id  \
# 0    clueweb22-pt0000-05-02747_0
# 1    clueweb22-pt0000-78-09747_0
# 2    clueweb22-pt0000-87-14633_2
# 3    clueweb22-pt0000-69-05954_7
# 4    clueweb22-pt0000-55-02859_0
# ..                           ...
# 495  clueweb22-pt0000-48-17441_2
# 496  clueweb22-pt0002-04-01418_0
# 497  clueweb22-pt0001-24-17228_0
# 498  clueweb22-pt0000-08-07683_2
# 499  clueweb22-pt0000-86-08729_0
#
#                                                  query  \
# 0     Qual a maior característica da fauna brasileira?
# 1     Qual a maior característica da fauna brasileira?
# 2     Qual a maior característica da fauna brasileira?
# 3     Qual a maior característica da fauna brasileira?
# 4     Qual a maior característica da fauna brasileira?
# ..                                                 ...
# 495  Quais foram os principais artistas do Impressi...
# 496  Quais foram os principais artistas do Impressi...
# 497  Quais foram os principais artistas do Impressi...
# 498  Quais foram os principais artistas do Impressi...
# 499  Quais foram os principais artistas do Impressi...
#
#                                                passage
# 0    BIOMAS E FITOFISIONOMIAS BRASILEIROS: CARACTER...
# 1    Onça-pintada - Escola Kids Qual matéria está p...
# 2    - Fauna e Flora A fauna da Amazônia é represen...
# 3    Aprenda sobre a Bacia do Tocantins-Araguaia, a...
# 4    Fauna e Flora: : entenda o que são e quais as ...
# ..                                                 ...
# 495  O IMPRESSIONISMO foi um movimento artístico qu...
# 496  O Impressionismo de Monet | Cultura - Cultura ...
# 497  A cultura da gare - 1534 Palavras | Trabalhosf...
# 498  Severini e o Cubismo Os traços do futurismo ga...
# 499  Eugène Boudin - 560 obras de arte - pintura In...
#
# [500 rows x 9 columns]

# %%
top_10_df.rename(columns={'clueweb_id': 'passage_id'}).to_csv(os.path.join(QUERIES_FOLDER, "bm25_massiveweb_1M_docs_000_009_sampled_50_queries.tsv"), sep="\t", index=False)

# %% [markdown]
# ### Check how many passages in the 1000 retrieved per query had already been analyzed by GPT-4

# %%
already_analized = 0

for i, row in run_file_converted_id.iterrows():
    if (row['query'] + "_" + row['clueweb_id']) in logs['evaluation_cache']:
        print("Already analized...")

        already_analized += 1
# Out:
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...
# Already analized...

# %%
already_analized
# Out:
# 260

# %%
'_'.join('Onde está localizada a Praça XV de Novembro?_clueweb22-pt0000-44-08794_4'.split('_')[1:])

# %%
all_analized_passages = ['_'.join(which_key.split('_')[1:]) for which_key in list(logs['evaluation_cache'].keys())]

# %%
len(all_analized_passages)

# %%
analized_passages = np.unique(all_analized_passages)

# %%
analized_passages.shape

# %%
pd.DataFrame(analized_passages, columns=["clueweb_id"]).merge(pd.DataFrame(dataset_with_clueweb_id_df['clueweb_id'].drop_duplicates()))
