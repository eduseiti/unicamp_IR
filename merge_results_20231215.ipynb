# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
first_df = pd.read_csv("tests/evaluation_04_retrievers_000_009_sampled_50_queries_gpt-4-1106-preview_20231211.tsv", sep="\t")

# %%
second_df = pd.read_csv("tests/evaluation_bm25_000_009_sampled_50_queries_gpt-4-1106-preview_20231215.tsv", sep="\t")

# %%
first_df.groupby("query").count()
# Out:
#                                                     query_id  passage_id  mT5  \
# query
# Como configurar uma linguagem do teclado window...        20          20   20
# Como deixar a internet rápida?                            28          28   28
# Como o Brasil reagiu a epidemia de AIDS no fim ...        25          25   25
# Como obter o visto EB-5?                                  21          21   21
# Como podemos classificar o relevo brasileiro?             24          24   24
# Como transformar uma cidade pacata em um polo t...        30          30   30
# Cuidados ao usar materiais perfurocortantes               26          26   26
# Delirio versus alucinação                                 28          28   28
# Existem vantagens ao definir uma moeda única?             27          27   27
# Fatores de risco para cancer de pele                      20          20   20
# Motivos para a saída de Jorge Jesus da Benfica?           21          21   21
# No que se difere o civismo da cidadania?                  28          28   28
# O que pode deixar a internet lenta?                       18          18   18
# O que são os celulares "mid-range"?                       35          35   35
# O que é a associação em série de um capacitor?            16          16   16
# Onde está localizada a Praça XV de Novembro?              26          26   26
# Opções de Seguro da Essor Seguros                         25          25   25
# Por que a legislação de um país é tão importante?         33          33   33
# Por que dividir um país em estados?                       30          30   30
# Por que os anos de 80 são considerados a década...        20          20   20
# Por que os países Guiana e Suriname não são fil...        28          28   28
# Quais as causas para lábios inflamados em crian...        27          27   27
# Quais as etapas de distribuição da coca-cola?             26          26   26
# Quais as formas de pagamento disponível no PagT...        20          20   20
# Quais as origens de pessoas com olhos verdes?             24          24   24
# Quais atitudes podem prejudicar a saúde mental?           26          26   26
# Quais foram os principais artistas do Impressio...        25          25   25
# Quais os sinonimos de eficiência relacionado a ...        27          27   27
# Quais os tipos de denominação (DO) que os vinho...        23          23   23
# Quais partidos já ocuparam o cargo da presidênc...        32          32   32
# Quais são os biomas do Brasil?                            29          29   29
# Quais são os melhores parques nacionais de Port...        28          28   28
# Quais são os principais intérpretes da música b...        33          33   33
# Qual a causa de pessoas com olho de cada cor?             29          29   29
# Qual a maior característica da fauna brasileira?          29          29   29
# Qual a maior torcida de futebol do Brasil?                17          17   17
# Qual a melhor cidade para ficar no Jalapão?               20          20   20
# Qual foi a importância da usina de Volta Redond...        23          23   23
# Qual o critério para classificação para a Copa ...        26          26   26
# Qual o nosso atual sistema de governo?                    33          33   33
# Qual o sistema de governo da África do Sul?               23          23   23
# Qual o uso dos códigos SWIFT?                             19          19   19
# Qual é a principal cidade do basquete brasileiro?         28          28   28
# Quando foi criada a consolidação das leis traba...        28          28   28
# Quando se realizou o plebiscito popular para de...        20          20   20
# Quando é o dia Mundial da Alimentação?                    17          17   17
# Quantas placas são formadas pelos materiais con...        39          39   39
# quais os critérios de definição dos monumentos ...        24          24   24
# quais países europeus seguem o regime monarquista?        28          28   28
# É possível conhecer o Pico da Bandeira com cria...        37          37   37
#
#                                                     splade  colbertx  bm25_e5  \
# query
# Como configurar uma linguagem do teclado window...      20        20       20
# Como deixar a internet rápida?                          28        28       28
# Como o Brasil reagiu a epidemia de AIDS no fim ...      25        25       25
# Como obter o visto EB-5?                                21        21       21
# Como podemos classificar o relevo brasileiro?           24        24       24
# Como transformar uma cidade pacata em um polo t...      30        30       30
# Cuidados ao usar materiais perfurocortantes             26        26       26
# Delirio versus alucinação                               28        28       28
# Existem vantagens ao definir uma moeda única?           27        27       27
# Fatores de risco para cancer de pele                    20        20       20
# Motivos para a saída de Jorge Jesus da Benfica?         21        21       21
# No que se difere o civismo da cidadania?                28        28       28
# O que pode deixar a internet lenta?                     18        18       18
# O que são os celulares "mid-range"?                     35        35       35
# O que é a associação em série de um capacitor?          16        16       16
# Onde está localizada a Praça XV de Novembro?            26        26       26
# Opções de Seguro da Essor Seguros                       25        25       25
# Por que a legislação de um país é tão importante?       33        33       33
# Por que dividir um país em estados?                     30        30       30
# Por que os anos de 80 são considerados a década...      20        20       20
# Por que os países Guiana e Suriname não são fil...      28        28       28
# Quais as causas para lábios inflamados em crian...      27        27       27
# Quais as etapas de distribuição da coca-cola?           26        26       26
# Quais as formas de pagamento disponível no PagT...      20        20       20
# Quais as origens de pessoas com olhos verdes?           24        24       24
# Quais atitudes podem prejudicar a saúde mental?         26        26       26
# Quais foram os principais artistas do Impressio...      25        25       25
# Quais os sinonimos de eficiência relacionado a ...      27        27       27
# Quais os tipos de denominação (DO) que os vinho...      23        23       23
# Quais partidos já ocuparam o cargo da presidênc...      32        32       32
# Quais são os biomas do Brasil?                          29        29       29
# Quais são os melhores parques nacionais de Port...      28        28       28
# Quais são os principais intérpretes da música b...      33        33       33
# Qual a causa de pessoas com olho de cada cor?           29        29       29
# Qual a maior característica da fauna brasileira?        29        29       29
# Qual a maior torcida de futebol do Brasil?              17        17       17
# Qual a melhor cidade para ficar no Jalapão?             20        20       20
# Qual foi a importância da usina de Volta Redond...      23        23       23
# Qual o critério para classificação para a Copa ...      26        26       26
# Qual o nosso atual sistema de governo?                  33        33       33
# Qual o sistema de governo da África do Sul?             23        23       23
# Qual o uso dos códigos SWIFT?                           19        19       19
# Qual é a principal cidade do basquete brasileiro?       28        28       28
# Quando foi criada a consolidação das leis traba...      28        28       28
# Quando se realizou o plebiscito popular para de...      20        20       20
# Quando é o dia Mundial da Alimentação?                  17        17       17
# Quantas placas são formadas pelos materiais con...      39        39       39
# quais os critérios de definição dos monumentos ...      24        24       24
# quais países europeus seguem o regime monarquista?      28        28       28
# É possível conhecer o Pico da Bandeira com cria...      37        37       37
#
#                                                     passage  score  reasoning  \
# query
# Como configurar uma linguagem do teclado window...       20     20         20
# Como deixar a internet rápida?                           28     28         28
# Como o Brasil reagiu a epidemia de AIDS no fim ...       25     25         25
# Como obter o visto EB-5?                                 21     21         21
# Como podemos classificar o relevo brasileiro?            24     24         24
# Como transformar uma cidade pacata em um polo t...       30     30         30
# Cuidados ao usar materiais perfurocortantes              26     26         26
# Delirio versus alucinação                                28     28         28
# Existem vantagens ao definir uma moeda única?            27     27         27
# Fatores de risco para cancer de pele                     20     20         20
# Motivos para a saída de Jorge Jesus da Benfica?          21     21         21
# No que se difere o civismo da cidadania?                 28     28         28
# O que pode deixar a internet lenta?                      18     18         18
# O que são os celulares "mid-range"?                      35     35         35
# O que é a associação em série de um capacitor?           16     16         16
# Onde está localizada a Praça XV de Novembro?             26     26         26
# Opções de Seguro da Essor Seguros                        25     25         25
# Por que a legislação de um país é tão importante?        33     33         33
# Por que dividir um país em estados?                      30     30         30
# Por que os anos de 80 são considerados a década...       20     20         20
# Por que os países Guiana e Suriname não são fil...       28     28         28
# Quais as causas para lábios inflamados em crian...       27     27         27
# Quais as etapas de distribuição da coca-cola?            26     26         26
# Quais as formas de pagamento disponível no PagT...       20     20         20
# Quais as origens de pessoas com olhos verdes?            24     24         24
# Quais atitudes podem prejudicar a saúde mental?          26     26         26
# Quais foram os principais artistas do Impressio...       25     25         25
# Quais os sinonimos de eficiência relacionado a ...       27     27         27
# Quais os tipos de denominação (DO) que os vinho...       23     23         23
# Quais partidos já ocuparam o cargo da presidênc...       32     32         32
# Quais são os biomas do Brasil?                           29     29         29
# Quais são os melhores parques nacionais de Port...       28     28         28
# Quais são os principais intérpretes da música b...       33     33         33
# Qual a causa de pessoas com olho de cada cor?            29     29         29
# Qual a maior característica da fauna brasileira?         29     29         29
# Qual a maior torcida de futebol do Brasil?               17     17         17
# Qual a melhor cidade para ficar no Jalapão?              20     20         20
# Qual foi a importância da usina de Volta Redond...       23     23         23
# Qual o critério para classificação para a Copa ...       26     26         26
# Qual o nosso atual sistema de governo?                   33     33         33
# Qual o sistema de governo da África do Sul?              23     23         23
# Qual o uso dos códigos SWIFT?                            19     19         19
# Qual é a principal cidade do basquete brasileiro?        28     28         28
# Quando foi criada a consolidação das leis traba...       28     28         28
# Quando se realizou o plebiscito popular para de...       20     20         20
# Quando é o dia Mundial da Alimentação?                   17     17         17
# Quantas placas são formadas pelos materiais con...       39     39         39
# quais os critérios de definição dos monumentos ...       24     24         24
# quais países europeus seguem o regime monarquista?       28     28         28
# É possível conhecer o Pico da Bandeira com cria...       37     37         37
#
#                                                     usage  cost  duration  \
# query
# Como configurar uma linguagem do teclado window...     20    20        20
# Como deixar a internet rápida?                         28    28        28
# Como o Brasil reagiu a epidemia de AIDS no fim ...     25    25        25
# Como obter o visto EB-5?                               21    21        21
# Como podemos classificar o relevo brasileiro?          24    24        24
# Como transformar uma cidade pacata em um polo t...     30    30        30
# Cuidados ao usar materiais perfurocortantes            26    26        26
# Delirio versus alucinação                              28    28        28
# Existem vantagens ao definir uma moeda única?          27    27        27
# Fatores de risco para cancer de pele                   20    20        20
# Motivos para a saída de Jorge Jesus da Benfica?        21    21        21
# No que se difere o civismo da cidadania?               28    28        28
# O que pode deixar a internet lenta?                    18    18        18
# O que são os celulares "mid-range"?                    35    35        35
# O que é a associação em série de um capacitor?         16    16        16
# Onde está localizada a Praça XV de Novembro?           26    26        26
# Opções de Seguro da Essor Seguros                      25    25        25
# Por que a legislação de um país é tão importante?      33    33        33
# Por que dividir um país em estados?                    30    30        30
# Por que os anos de 80 são considerados a década...     20    20        20
# Por que os países Guiana e Suriname não são fil...     28    28        28
# Quais as causas para lábios inflamados em crian...     27    27        27
# Quais as etapas de distribuição da coca-cola?          26    26        26
# Quais as formas de pagamento disponível no PagT...     20    20        20
# Quais as origens de pessoas com olhos verdes?          24    24        24
# Quais atitudes podem prejudicar a saúde mental?        26    26        26
# Quais foram os principais artistas do Impressio...     25    25        25
# Quais os sinonimos de eficiência relacionado a ...     27    27        27
# Quais os tipos de denominação (DO) que os vinho...     23    23        23
# Quais partidos já ocuparam o cargo da presidênc...     32    32        32
# Quais são os biomas do Brasil?                         29    29        29
# Quais são os melhores parques nacionais de Port...     28    28        28
# Quais são os principais intérpretes da música b...     33    33        33
# Qual a causa de pessoas com olho de cada cor?          29    29        29
# Qual a maior característica da fauna brasileira?       29    29        29
# Qual a maior torcida de futebol do Brasil?             17    17        17
# Qual a melhor cidade para ficar no Jalapão?            20    20        20
# Qual foi a importância da usina de Volta Redond...     23    23        23
# Qual o critério para classificação para a Copa ...     26    26        26
# Qual o nosso atual sistema de governo?                 33    33        33
# Qual o sistema de governo da África do Sul?            23    23        23
# Qual o uso dos códigos SWIFT?                          19    19        19
# Qual é a principal cidade do basquete brasileiro?      28    28        28
# Quando foi criada a consolidação das leis traba...     28    28        28
# Quando se realizou o plebiscito popular para de...     20    20        20
# Quando é o dia Mundial da Alimentação?                 17    17        17
# Quantas placas são formadas pelos materiais con...     39    39        39
# quais os critérios de definição dos monumentos ...     24    24        24
# quais países europeus seguem o regime monarquista?     28    28        28
# É possível conhecer o Pico da Bandeira com cria...     37    37        37
#
#                                                     saved_cost
# query
# Como configurar uma linguagem do teclado window...          20
# Como deixar a internet rápida?                              28
# Como o Brasil reagiu a epidemia de AIDS no fim ...          25
# Como obter o visto EB-5?                                    21
# Como podemos classificar o relevo brasileiro?               24
# Como transformar uma cidade pacata em um polo t...          30
# Cuidados ao usar materiais perfurocortantes                 26
# Delirio versus alucinação                                   28
# Existem vantagens ao definir uma moeda única?               27
# Fatores de risco para cancer de pele                        20
# Motivos para a saída de Jorge Jesus da Benfica?             21
# No que se difere o civismo da cidadania?                    28
# O que pode deixar a internet lenta?                         18
# O que são os celulares "mid-range"?                         35
# O que é a associação em série de um capacitor?              16
# Onde está localizada a Praça XV de Novembro?                26
# Opções de Seguro da Essor Seguros                           25
# Por que a legislação de um país é tão importante?           33
# Por que dividir um país em estados?                         30
# Por que os anos de 80 são considerados a década...          20
# Por que os países Guiana e Suriname não são fil...          28
# Quais as causas para lábios inflamados em crian...          27
# Quais as etapas de distribuição da coca-cola?               26
# Quais as formas de pagamento disponível no PagT...          20
# Quais as origens de pessoas com olhos verdes?               24
# Quais atitudes podem prejudicar a saúde mental?             26
# Quais foram os principais artistas do Impressio...          25
# Quais os sinonimos de eficiência relacionado a ...          27
# Quais os tipos de denominação (DO) que os vinho...          23
# Quais partidos já ocuparam o cargo da presidênc...          32
# Quais são os biomas do Brasil?                              29
# Quais são os melhores parques nacionais de Port...          28
# Quais são os principais intérpretes da música b...          33
# Qual a causa de pessoas com olho de cada cor?               29
# Qual a maior característica da fauna brasileira?            29
# Qual a maior torcida de futebol do Brasil?                  17
# Qual a melhor cidade para ficar no Jalapão?                 20
# Qual foi a importância da usina de Volta Redond...          23
# Qual o critério para classificação para a Copa ...          26
# Qual o nosso atual sistema de governo?                      33
# Qual o sistema de governo da África do Sul?                 23
# Qual o uso dos códigos SWIFT?                               19
# Qual é a principal cidade do basquete brasileiro?           28
# Quando foi criada a consolidação das leis traba...          28
# Quando se realizou o plebiscito popular para de...          20
# Quando é o dia Mundial da Alimentação?                      17
# Quantas placas são formadas pelos materiais con...          39
# quais os critérios de definição dos monumentos ...          24
# quais países europeus seguem o regime monarquista?          28
# É possível conhecer o Pico da Bandeira com cria...          37

# %%
second_df.groupby("query").count()
# Out:
#                                                     passage_id  passage  \
# query
# Como configurar uma linguagem do teclado window...          10       10
# Como deixar a internet rápida?                              10       10
# Como o Brasil reagiu a epidemia de AIDS no fim ...          10       10
# Como obter o visto EB-5?                                    10       10
# Como podemos classificar o relevo brasileiro?               10       10
# Como transformar uma cidade pacata em um polo t...          10       10
# Cuidados ao usar materiais perfurocortantes                 10       10
# Delirio versus alucinação                                   10       10
# Existem vantagens ao definir uma moeda única?               10       10
# Fatores de risco para cancer de pele                        10       10
# Motivos para a saída de Jorge Jesus da Benfica?             10       10
# No que se difere o civismo da cidadania?                    10       10
# O que pode deixar a internet lenta?                         10       10
# O que são os celulares "mid-range"?                         10       10
# O que é a associação em série de um capacitor?              10       10
# Onde está localizada a Praça XV de Novembro?                10       10
# Opções de Seguro da Essor Seguros                           10       10
# Por que a legislação de um país é tão importante?           10       10
# Por que dividir um país em estados?                         10       10
# Por que os anos de 80 são considerados a década...          10       10
# Por que os países Guiana e Suriname não são fil...          10       10
# Quais as causas para lábios inflamados em crian...          10       10
# Quais as etapas de distribuição da coca-cola?               10       10
# Quais as formas de pagamento disponível no PagT...          10       10
# Quais as origens de pessoas com olhos verdes?               10       10
# Quais atitudes podem prejudicar a saúde mental?             10       10
# Quais foram os principais artistas do Impressio...          10       10
# Quais os sinonimos de eficiência relacionado a ...          10       10
# Quais os tipos de denominação (DO) que os vinho...          10       10
# Quais partidos já ocuparam o cargo da presidênc...          10       10
# Quais são os biomas do Brasil?                              10       10
# Quais são os melhores parques nacionais de Port...          10       10
# Quais são os principais intérpretes da música b...          10       10
# Qual a causa de pessoas com olho de cada cor?               10       10
# Qual a maior característica da fauna brasileira?            10       10
# Qual a maior torcida de futebol do Brasil?                  10       10
# Qual a melhor cidade para ficar no Jalapão?                 10       10
# Qual foi a importância da usina de Volta Redond...          10       10
# Qual o critério para classificação para a Copa ...          10       10
# Qual o nosso atual sistema de governo?                      10       10
# Qual o sistema de governo da África do Sul?                 10       10
# Qual o uso dos códigos SWIFT?                               10       10
# Qual é a principal cidade do basquete brasileiro?           10       10
# Quando foi criada a consolidação das leis traba...          10       10
# Quando se realizou o plebiscito popular para de...          10       10
# Quando é o dia Mundial da Alimentação?                      10       10
# Quantas placas são formadas pelos materiais con...          10       10
# quais os critérios de definição dos monumentos ...          10       10
# quais países europeus seguem o regime monarquista?          10       10
# É possível conhecer o Pico da Bandeira com cria...          10       10
#
#                                                     query_id_x  score  \
# query
# Como configurar uma linguagem do teclado window...          10     10
# Como deixar a internet rápida?                              10     10
# Como o Brasil reagiu a epidemia de AIDS no fim ...          10     10
# Como obter o visto EB-5?                                    10     10
# Como podemos classificar o relevo brasileiro?               10     10
# Como transformar uma cidade pacata em um polo t...          10     10
# Cuidados ao usar materiais perfurocortantes                 10     10
# Delirio versus alucinação                                   10     10
# Existem vantagens ao definir uma moeda única?               10     10
# Fatores de risco para cancer de pele                        10     10
# Motivos para a saída de Jorge Jesus da Benfica?             10     10
# No que se difere o civismo da cidadania?                    10     10
# O que pode deixar a internet lenta?                         10     10
# O que são os celulares "mid-range"?                         10     10
# O que é a associação em série de um capacitor?              10     10
# Onde está localizada a Praça XV de Novembro?                10     10
# Opções de Seguro da Essor Seguros                           10     10
# Por que a legislação de um país é tão importante?           10     10
# Por que dividir um país em estados?                         10     10
# Por que os anos de 80 são considerados a década...          10     10
# Por que os países Guiana e Suriname não são fil...          10     10
# Quais as causas para lábios inflamados em crian...          10     10
# Quais as etapas de distribuição da coca-cola?               10     10
# Quais as formas de pagamento disponível no PagT...          10     10
# Quais as origens de pessoas com olhos verdes?               10     10
# Quais atitudes podem prejudicar a saúde mental?             10     10
# Quais foram os principais artistas do Impressio...          10     10
# Quais os sinonimos de eficiência relacionado a ...          10     10
# Quais os tipos de denominação (DO) que os vinho...          10     10
# Quais partidos já ocuparam o cargo da presidênc...          10     10
# Quais são os biomas do Brasil?                              10     10
# Quais são os melhores parques nacionais de Port...          10     10
# Quais são os principais intérpretes da música b...          10     10
# Qual a causa de pessoas com olho de cada cor?               10     10
# Qual a maior característica da fauna brasileira?            10     10
# Qual a maior torcida de futebol do Brasil?                  10     10
# Qual a melhor cidade para ficar no Jalapão?                 10     10
# Qual foi a importância da usina de Volta Redond...          10     10
# Qual o critério para classificação para a Copa ...          10     10
# Qual o nosso atual sistema de governo?                      10     10
# Qual o sistema de governo da África do Sul?                 10     10
# Qual o uso dos códigos SWIFT?                               10     10
# Qual é a principal cidade do basquete brasileiro?           10     10
# Quando foi criada a consolidação das leis traba...          10     10
# Quando se realizou o plebiscito popular para de...          10     10
# Quando é o dia Mundial da Alimentação?                      10     10
# Quantas placas são formadas pelos materiais con...          10     10
# quais os critérios de definição dos monumentos ...          10     10
# quais países europeus seguem o regime monarquista?          10     10
# É possível conhecer o Pico da Bandeira com cria...          10     10
#
#                                                     query_id_y  score.1  \
# query
# Como configurar uma linguagem do teclado window...          10       10
# Como deixar a internet rápida?                              10       10
# Como o Brasil reagiu a epidemia de AIDS no fim ...          10       10
# Como obter o visto EB-5?                                    10       10
# Como podemos classificar o relevo brasileiro?               10       10
# Como transformar uma cidade pacata em um polo t...          10       10
# Cuidados ao usar materiais perfurocortantes                 10       10
# Delirio versus alucinação                                   10       10
# Existem vantagens ao definir uma moeda única?               10       10
# Fatores de risco para cancer de pele                        10       10
# Motivos para a saída de Jorge Jesus da Benfica?             10       10
# No que se difere o civismo da cidadania?                    10       10
# O que pode deixar a internet lenta?                         10       10
# O que são os celulares "mid-range"?                         10       10
# O que é a associação em série de um capacitor?              10       10
# Onde está localizada a Praça XV de Novembro?                10       10
# Opções de Seguro da Essor Seguros                           10       10
# Por que a legislação de um país é tão importante?           10       10
# Por que dividir um país em estados?                         10       10
# Por que os anos de 80 são considerados a década...          10       10
# Por que os países Guiana e Suriname não são fil...          10       10
# Quais as causas para lábios inflamados em crian...          10       10
# Quais as etapas de distribuição da coca-cola?               10       10
# Quais as formas de pagamento disponível no PagT...          10       10
# Quais as origens de pessoas com olhos verdes?               10       10
# Quais atitudes podem prejudicar a saúde mental?             10       10
# Quais foram os principais artistas do Impressio...          10       10
# Quais os sinonimos de eficiência relacionado a ...          10       10
# Quais os tipos de denominação (DO) que os vinho...          10       10
# Quais partidos já ocuparam o cargo da presidênc...          10       10
# Quais são os biomas do Brasil?                              10       10
# Quais são os melhores parques nacionais de Port...          10       10
# Quais são os principais intérpretes da música b...          10       10
# Qual a causa de pessoas com olho de cada cor?               10       10
# Qual a maior característica da fauna brasileira?            10       10
# Qual a maior torcida de futebol do Brasil?                  10       10
# Qual a melhor cidade para ficar no Jalapão?                 10       10
# Qual foi a importância da usina de Volta Redond...          10       10
# Qual o critério para classificação para a Copa ...          10       10
# Qual o nosso atual sistema de governo?                      10       10
# Qual o sistema de governo da África do Sul?                 10       10
# Qual o uso dos códigos SWIFT?                               10       10
# Qual é a principal cidade do basquete brasileiro?           10       10
# Quando foi criada a consolidação das leis traba...          10       10
# Quando se realizou o plebiscito popular para de...          10       10
# Quando é o dia Mundial da Alimentação?                      10       10
# Quantas placas são formadas pelos materiais con...          10       10
# quais os critérios de definição dos monumentos ...          10       10
# quais países europeus seguem o regime monarquista?          10       10
# É possível conhecer o Pico da Bandeira com cria...          10       10
#
#                                                     reasoning  usage  cost  \
# query
# Como configurar uma linguagem do teclado window...         10     10    10
# Como deixar a internet rápida?                             10     10    10
# Como o Brasil reagiu a epidemia de AIDS no fim ...         10     10    10
# Como obter o visto EB-5?                                   10     10    10
# Como podemos classificar o relevo brasileiro?              10     10    10
# Como transformar uma cidade pacata em um polo t...         10     10    10
# Cuidados ao usar materiais perfurocortantes                10     10    10
# Delirio versus alucinação                                  10     10    10
# Existem vantagens ao definir uma moeda única?              10     10    10
# Fatores de risco para cancer de pele                       10     10    10
# Motivos para a saída de Jorge Jesus da Benfica?            10     10    10
# No que se difere o civismo da cidadania?                   10     10    10
# O que pode deixar a internet lenta?                        10     10    10
# O que são os celulares "mid-range"?                        10     10    10
# O que é a associação em série de um capacitor?             10     10    10
# Onde está localizada a Praça XV de Novembro?               10     10    10
# Opções de Seguro da Essor Seguros                          10     10    10
# Por que a legislação de um país é tão importante?          10     10    10
# Por que dividir um país em estados?                        10     10    10
# Por que os anos de 80 são considerados a década...         10     10    10
# Por que os países Guiana e Suriname não são fil...         10     10    10
# Quais as causas para lábios inflamados em crian...         10     10    10
# Quais as etapas de distribuição da coca-cola?              10     10    10
# Quais as formas de pagamento disponível no PagT...         10     10    10
# Quais as origens de pessoas com olhos verdes?              10     10    10
# Quais atitudes podem prejudicar a saúde mental?            10     10    10
# Quais foram os principais artistas do Impressio...         10     10    10
# Quais os sinonimos de eficiência relacionado a ...         10     10    10
# Quais os tipos de denominação (DO) que os vinho...         10     10    10
# Quais partidos já ocuparam o cargo da presidênc...         10     10    10
# Quais são os biomas do Brasil?                             10     10    10
# Quais são os melhores parques nacionais de Port...         10     10    10
# Quais são os principais intérpretes da música b...         10     10    10
# Qual a causa de pessoas com olho de cada cor?              10     10    10
# Qual a maior característica da fauna brasileira?           10     10    10
# Qual a maior torcida de futebol do Brasil?                 10     10    10
# Qual a melhor cidade para ficar no Jalapão?                10     10    10
# Qual foi a importância da usina de Volta Redond...         10     10    10
# Qual o critério para classificação para a Copa ...         10     10    10
# Qual o nosso atual sistema de governo?                     10     10    10
# Qual o sistema de governo da África do Sul?                10     10    10
# Qual o uso dos códigos SWIFT?                              10     10    10
# Qual é a principal cidade do basquete brasileiro?          10     10    10
# Quando foi criada a consolidação das leis traba...         10     10    10
# Quando se realizou o plebiscito popular para de...         10     10    10
# Quando é o dia Mundial da Alimentação?                     10     10    10
# Quantas placas são formadas pelos materiais con...         10     10    10
# quais os critérios de definição dos monumentos ...         10     10    10
# quais países europeus seguem o regime monarquista?         10     10    10
# É possível conhecer o Pico da Bandeira com cria...         10     10    10
#
#                                                     duration  saved_cost
# query
# Como configurar uma linguagem do teclado window...        10          10
# Como deixar a internet rápida?                            10          10
# Como o Brasil reagiu a epidemia de AIDS no fim ...        10          10
# Como obter o visto EB-5?                                  10          10
# Como podemos classificar o relevo brasileiro?             10          10
# Como transformar uma cidade pacata em um polo t...        10          10
# Cuidados ao usar materiais perfurocortantes               10          10
# Delirio versus alucinação                                 10          10
# Existem vantagens ao definir uma moeda única?             10          10
# Fatores de risco para cancer de pele                      10          10
# Motivos para a saída de Jorge Jesus da Benfica?           10          10
# No que se difere o civismo da cidadania?                  10          10
# O que pode deixar a internet lenta?                       10          10
# O que são os celulares "mid-range"?                       10          10
# O que é a associação em série de um capacitor?            10          10
# Onde está localizada a Praça XV de Novembro?              10          10
# Opções de Seguro da Essor Seguros                         10          10
# Por que a legislação de um país é tão importante?         10          10
# Por que dividir um país em estados?                       10          10
# Por que os anos de 80 são considerados a década...        10          10
# Por que os países Guiana e Suriname não são fil...        10          10
# Quais as causas para lábios inflamados em crian...        10          10
# Quais as etapas de distribuição da coca-cola?             10          10
# Quais as formas de pagamento disponível no PagT...        10          10
# Quais as origens de pessoas com olhos verdes?             10          10
# Quais atitudes podem prejudicar a saúde mental?           10          10
# Quais foram os principais artistas do Impressio...        10          10
# Quais os sinonimos de eficiência relacionado a ...        10          10
# Quais os tipos de denominação (DO) que os vinho...        10          10
# Quais partidos já ocuparam o cargo da presidênc...        10          10
# Quais são os biomas do Brasil?                            10          10
# Quais são os melhores parques nacionais de Port...        10          10
# Quais são os principais intérpretes da música b...        10          10
# Qual a causa de pessoas com olho de cada cor?             10          10
# Qual a maior característica da fauna brasileira?          10          10
# Qual a maior torcida de futebol do Brasil?                10          10
# Qual a melhor cidade para ficar no Jalapão?               10          10
# Qual foi a importância da usina de Volta Redond...        10          10
# Qual o critério para classificação para a Copa ...        10          10
# Qual o nosso atual sistema de governo?                    10          10
# Qual o sistema de governo da África do Sul?               10          10
# Qual o uso dos códigos SWIFT?                             10          10
# Qual é a principal cidade do basquete brasileiro?         10          10
# Quando foi criada a consolidação das leis traba...        10          10
# Quando se realizou o plebiscito popular para de...        10          10
# Quando é o dia Mundial da Alimentação?                    10          10
# Quantas placas são formadas pelos materiais con...        10          10
# quais os critérios de definição dos monumentos ...        10          10
# quais países europeus seguem o regime monarquista?        10          10
# É possível conhecer o Pico da Bandeira com cria...        10          10

# %%
first_df.head()
# Out:
#    query_id                                             query  \
# 0         1  Qual a maior característica da fauna brasileira?
# 1         1  Qual a maior característica da fauna brasileira?
# 2         1  Qual a maior característica da fauna brasileira?
# 3         1  Qual a maior característica da fauna brasileira?
# 4         1  Qual a maior característica da fauna brasileira?
#
#                      passage_id    mT5  splade  colbertx  bm25_e5  \
# 0   clueweb22-pt0000-82-13187_0  False   False      True    False
# 1   clueweb22-pt0000-59-04599_2  False   False      True    False
# 2  clueweb22-pt0000-64-06285_39   True    True     False    False
# 3   clueweb22-pt0000-77-06884_1  False    True      True    False
# 4   clueweb22-pt0000-78-09747_0   True   False     False    False
#
#                                              passage  score  \
# 0  Mamíferos do Brasil - Zoologia | Museu Naciona...      1
# 1  Segundo uma lista levantada pelo Comitê Brasil...      1
# 2  A exuberante fauna e flora brasileiras, relata...      3
# 3  O tamanho do Brasil e a grande variedade de cl...      1
# 4  Onça-pintada - Escola Kids Qual matéria está p...      1
#
#                                            reasoning  \
# 0  A passagem lista vários mamíferos da fauna bra...
# 1  A passagem descreve várias espécies de aves en...
# 2  A passagem menciona que o Brasil tem a maior b...
# 3  A passagem menciona a alta biodiversidade do B...
# 4  A passagem menciona que a onça-pintada é um do...
#
#                                                usage  cost  duration  \
# 0  {'prompt_tokens': 765, 'completion_tokens': 75...   0.0  6.693229
# 1  {'prompt_tokens': 860, 'completion_tokens': 82...   0.0  5.163547
# 2  {'prompt_tokens': 840, 'completion_tokens': 46...   0.0  5.185688
# 3  {'prompt_tokens': 812, 'completion_tokens': 81...   0.0  5.882017
# 4  {'prompt_tokens': 805, 'completion_tokens': 96...   0.0  5.774773
#
#    saved_cost
# 0     0.02745
# 1     0.03072
# 2     0.02796
# 3     0.02922
# 4     0.02991

# %%
second_df.head()
# Out:
#                                           query                    passage_id  \
# 0  Onde está localizada a Praça XV de Novembro?   clueweb22-pt0001-30-20122_4
# 1  Onde está localizada a Praça XV de Novembro?   clueweb22-pt0001-14-16263_0
# 2  Onde está localizada a Praça XV de Novembro?   clueweb22-pt0000-25-03447_1
# 3  Onde está localizada a Praça XV de Novembro?   clueweb22-pt0001-84-16421_6
# 4  Onde está localizada a Praça XV de Novembro?  clueweb22-pt0001-72-12813_23
#
#                                              passage  query_id_x  score  \
# 0  Dali, vá até a Rua XV de Novembro, passando pe...         105    100
# 1  Praça XV (Rio de Janeiro) – Wikipédia, a encic...         105     90
# 2  Seguindo a Rua XV de Novembro chega-se ao Teat...         105     80
# 3  Com a inauguração da “PARADA XV”, começaram a ...         105     70
# 4  Nas demais cidades do estado, há ruas homenage...         105     60
#
#    query_id_y  score.1                                          reasoning  \
# 0         105        0  A passagem não menciona a localização da Praça...
# 1         105        3  A passagem responde diretamente à pergunta, fo...
# 2         105        0  A passagem não menciona a localização da Praça...
# 3         105        0  A passagem não especifica a localização geográ...
# 4         105        0  A passagem menciona a Rua XV de Novembro, mas ...
#
#                                                usage    cost  duration  \
# 0  {'prompt_tokens': 872, 'completion_tokens': 76...  0.0000  5.165271
# 1  {'prompt_tokens': 887, 'completion_tokens': 56...  0.0000  6.044610
# 2  {'prompt_tokens': 767, 'completion_tokens': 74...  0.0000  6.192222
# 3  {'prompt_tokens': 782, 'completion_tokens': 73...  0.0000  5.246655
# 4  {'prompt_tokens': 892, 'completion_tokens': 79...  0.0315  5.325507
#
#    saved_cost
# 0     0.03072
# 1     0.02997
# 2     0.02745
# 3     0.02784
# 4     0.00000

# %% [markdown]
# ### Merge both results

# %%
results = []

for group_name, group_df in first_df.groupby('query_id'):

    print("\nHandling query_id={}".format(group_name))
    
    query_df = second_df[second_df['query_id_x'] == group_name]
    query_docs = []
    passages = group_df['passage_id'].to_numpy()
    bm25_passages = query_df['passage_id'].to_numpy()
  
    print("-- Existing passages={}\n-- BM25 only passages={}".format(passages.shape[0],
                                                                     10 - np.intersect1d(passages, bm25_passages).shape[0]))
    
    for i, row in group_df.iterrows():

        # print(row)
        
        query_docs.append({"query_id": group_name,
                           "query": row['query'],
                           "passage_id": row['passage_id'],
                           "mT5": row['mT5'],
                           "splade": row['splade'],
                           "colbertx": row['colbertx'],
                           "bm25_e5": row['bm25_e5'],
                           "bm25": row['passage_id'] in bm25_passages,
                           "passage": row['passage'],
                           "score": row['score'],
                           "reasoning": row['reasoning'],
                           "usage": row['usage'],
                           "cost": row['cost'],
                           "duration": row['duration'],
                           "saved_cost": row['saved_cost']})

    for i, row in query_df.iterrows():
        if row['passage_id'] not in passages:
            query_docs.append({"query_id": group_name,
                               "query": row['query'],
                               "passage_id": row['passage_id'],
                               "mT5": False,
                               "splade": False,
                               "colbertx": False,
                               "bm25_e5": False,
                               "bm25": True,
                               "passage": row['passage'],
                               "score": row['score.1'],
                               "reasoning": row['reasoning'],
                               "usage": row['usage'],
                               "cost": row['cost'],
                               "duration": row['duration'],
                               "saved_cost": row['saved_cost']})                               

    print("-- Final number of passages={}".format(len(query_docs)))

    results += query_docs
# Out:
# Handling query_id=1
# -- Existing passages=29
# -- BM25 only passages=6
# -- Final number of passages-35
#
# Handling query_id=2
# -- Existing passages=28
# -- BM25 only passages=8
# -- Final number of passages-36
#
# Handling query_id=9
# -- Existing passages=28
# -- BM25 only passages=9
# -- Final number of passages-37
#
# Handling query_id=11
# -- Existing passages=24
# -- BM25 only passages=3
# -- Final number of passages-27
#
# Handling query_id=13
# -- Existing passages=25
# -- BM25 only passages=6
# -- Final number of passages-31
#
# Handling query_id=15
# -- Existing passages=17
# -- BM25 only passages=6
# -- Final number of passages-23
#
# Handling query_id=17
# -- Existing passages=20
# -- BM25 only passages=8
# -- Final number of passages-28
#
# Handling query_id=20
# -- Existing passages=33
# -- BM25 only passages=10
# -- Final number of passages-43
#
# Handling query_id=21
# -- Existing passages=33
# -- BM25 only passages=8
# -- Final number of passages-41
#
# Handling query_id=22
# -- Existing passages=23
# -- BM25 only passages=6
# -- Final number of passages-29
#
# Handling query_id=24
# -- Existing passages=30
# -- BM25 only passages=9
# -- Final number of passages-39
#
# Handling query_id=26
# -- Existing passages=24
# -- BM25 only passages=4
# -- Final number of passages-28
#
# Handling query_id=28
# -- Existing passages=27
# -- BM25 only passages=7
# -- Final number of passages-34
#
# Handling query_id=47
# -- Existing passages=30
# -- BM25 only passages=9
# -- Final number of passages-39
#
# Handling query_id=49
# -- Existing passages=28
# -- BM25 only passages=6
# -- Final number of passages-34
#
# Handling query_id=51
# -- Existing passages=20
# -- BM25 only passages=3
# -- Final number of passages-23
#
# Handling query_id=54
# -- Existing passages=29
# -- BM25 only passages=7
# -- Final number of passages-36
#
# Handling query_id=60
# -- Existing passages=28
# -- BM25 only passages=4
# -- Final number of passages-32
#
# Handling query_id=62
# -- Existing passages=32
# -- BM25 only passages=9
# -- Final number of passages-41
#
# Handling query_id=64
# -- Existing passages=20
# -- BM25 only passages=4
# -- Final number of passages-24
#
# Handling query_id=68
# -- Existing passages=33
# -- BM25 only passages=10
# -- Final number of passages-43
#
# Handling query_id=84
# -- Existing passages=28
# -- BM25 only passages=7
# -- Final number of passages-35
#
# Handling query_id=95
# -- Existing passages=37
# -- BM25 only passages=6
# -- Final number of passages-43
#
# Handling query_id=98
# -- Existing passages=26
# -- BM25 only passages=7
# -- Final number of passages-33
#
# Handling query_id=105
# -- Existing passages=26
# -- BM25 only passages=3
# -- Final number of passages-29
#
# Handling query_id=113
# -- Existing passages=20
# -- BM25 only passages=5
# -- Final number of passages-25
#
# Handling query_id=115
# -- Existing passages=26
# -- BM25 only passages=7
# -- Final number of passages-33
#
# Handling query_id=117
# -- Existing passages=28
# -- BM25 only passages=7
# -- Final number of passages-35
#
# Handling query_id=126
# -- Existing passages=39
# -- BM25 only passages=8
# -- Final number of passages-47
#
# Handling query_id=127
# -- Existing passages=16
# -- BM25 only passages=2
# -- Final number of passages-18
#
# Handling query_id=128
# -- Existing passages=17
# -- BM25 only passages=2
# -- Final number of passages-19
#
# Handling query_id=136
# -- Existing passages=23
# -- BM25 only passages=8
# -- Final number of passages-31
#
# Handling query_id=147
# -- Existing passages=25
# -- BM25 only passages=4
# -- Final number of passages-29
#
# Handling query_id=152
# -- Existing passages=27
# -- BM25 only passages=7
# -- Final number of passages-34
#
# Handling query_id=153
# -- Existing passages=23
# -- BM25 only passages=8
# -- Final number of passages-31
#
# Handling query_id=154
# -- Existing passages=19
# -- BM25 only passages=9
# -- Final number of passages-28
#
# Handling query_id=160
# -- Existing passages=20
# -- BM25 only passages=1
# -- Final number of passages-21
#
# Handling query_id=161
# -- Existing passages=21
# -- BM25 only passages=4
# -- Final number of passages-25
#
# Handling query_id=163
# -- Existing passages=26
# -- BM25 only passages=5
# -- Final number of passages-31
#
# Handling query_id=167
# -- Existing passages=35
# -- BM25 only passages=7
# -- Final number of passages-42
#
# Handling query_id=170
# -- Existing passages=27
# -- BM25 only passages=5
# -- Final number of passages-32
#
# Handling query_id=172
# -- Existing passages=20
# -- BM25 only passages=5
# -- Final number of passages-25
#
# Handling query_id=180
# -- Existing passages=21
# -- BM25 only passages=7
# -- Final number of passages-28
#
# Handling query_id=181
# -- Existing passages=29
# -- BM25 only passages=8
# -- Final number of passages-37
#
# Handling query_id=182
# -- Existing passages=24
# -- BM25 only passages=8
# -- Final number of passages-32
#
# Handling query_id=189
# -- Existing passages=28
# -- BM25 only passages=4
# -- Final number of passages-32
#
# Handling query_id=193
# -- Existing passages=26
# -- BM25 only passages=9
# -- Final number of passages-35
#
# Handling query_id=195
# -- Existing passages=18
# -- BM25 only passages=8
# -- Final number of passages-26
#
# Handling query_id=196
# -- Existing passages=28
# -- BM25 only passages=7
# -- Final number of passages-35
#
# Handling query_id=199
# -- Existing passages=25
# -- BM25 only passages=9
# -- Final number of passages-34

# %%
len(results)
# Out:
# 1608

# %%
results_df = pd.DataFrame(results)

# %%
results_df
# Out:
#       query_id                                              query  \
# 0            1   Qual a maior característica da fauna brasileira?
# 1            1   Qual a maior característica da fauna brasileira?
# 2            1   Qual a maior característica da fauna brasileira?
# 3            1   Qual a maior característica da fauna brasileira?
# 4            1   Qual a maior característica da fauna brasileira?
# ...        ...                                                ...
# 1603       199  Quais foram os principais artistas do Impressi...
# 1604       199  Quais foram os principais artistas do Impressi...
# 1605       199  Quais foram os principais artistas do Impressi...
# 1606       199  Quais foram os principais artistas do Impressi...
# 1607       199  Quais foram os principais artistas do Impressi...
#
#                         passage_id    mT5  splade  colbertx  bm25_e5   bm25  \
# 0      clueweb22-pt0000-82-13187_0  False   False      True    False  False
# 1      clueweb22-pt0000-59-04599_2  False   False      True    False  False
# 2     clueweb22-pt0000-64-06285_39   True    True     False    False  False
# 3      clueweb22-pt0000-77-06884_1  False    True      True    False  False
# 4      clueweb22-pt0000-78-09747_0   True   False     False    False   True
# ...                            ...    ...     ...       ...      ...    ...
# 1603   clueweb22-pt0000-36-11451_3  False   False     False    False   True
# 1604   clueweb22-pt0001-34-12072_2  False   False     False    False   True
# 1605   clueweb22-pt0000-71-02344_0  False   False     False    False   True
# 1606   clueweb22-pt0001-15-16760_5  False   False     False    False   True
# 1607   clueweb22-pt0000-22-00963_2  False   False     False    False   True
#
#                                                 passage  score  \
# 0     Mamíferos do Brasil - Zoologia | Museu Naciona...      1
# 1     Segundo uma lista levantada pelo Comitê Brasil...      1
# 2     A exuberante fauna e flora brasileiras, relata...      3
# 3     O tamanho do Brasil e a grande variedade de cl...      1
# 4     Onça-pintada - Escola Kids Qual matéria está p...      1
# ...                                                 ...    ...
# 1603  Por conta disso, os artistas tiveram de encont...      0
# 1604  na sua opinião como podemos definir a dança e ...      0
# 1605  Pós-impressionismo: características, artistas ...      1
# 1606  Conheça a pintora modernista Anita Malfatti. S...      1
# 1607  Dessa forma, a principal diferença entre o imp...      0
#
#                                               reasoning  \
# 0     A passagem lista vários mamíferos da fauna bra...
# 1     A passagem descreve várias espécies de aves en...
# 2     A passagem menciona que o Brasil tem a maior b...
# 3     A passagem menciona a alta biodiversidade do B...
# 4     A passagem menciona que a onça-pintada é um do...
# ...                                                 ...
# 1603  A passagem fala sobre o Pós-Impressionismo e s...
# 1604  A passagem menciona o impressionismo, mas não ...
# 1605  A passagem discute o pós-impressionismo e menc...
# 1606  A passagem menciona o movimento impressionista...
# 1607  A passagem discute a diferença entre impressio...
#
#                                                   usage     cost  duration  \
# 0     {'prompt_tokens': 765, 'completion_tokens': 75...  0.00000  6.693229
# 1     {'prompt_tokens': 860, 'completion_tokens': 82...  0.00000  5.163547
# 2     {'prompt_tokens': 840, 'completion_tokens': 46...  0.00000  5.185688
# 3     {'prompt_tokens': 812, 'completion_tokens': 81...  0.00000  5.882017
# 4     {'prompt_tokens': 805, 'completion_tokens': 96...  0.00000  5.774773
# ...                                                 ...      ...       ...
# 1603  {'prompt_tokens': 809, 'completion_tokens': 64...  0.02811  6.493797
# 1604  {'prompt_tokens': 660, 'completion_tokens': 69...  0.02394  8.859752
# 1605  {'prompt_tokens': 844, 'completion_tokens': 61...  0.02898  4.820126
# 1606  {'prompt_tokens': 696, 'completion_tokens': 64...  0.02472  5.035404
# 1607  {'prompt_tokens': 813, 'completion_tokens': 63...  0.02817  7.622055
#
#       saved_cost
# 0        0.02745
# 1        0.03072
# 2        0.02796
# 3        0.02922
# 4        0.02991
# ...          ...
# 1603     0.00000
# 1604     0.00000
# 1605     0.00000
# 1606     0.00000
# 1607     0.00000
#
# [1608 rows x 15 columns]

# %%
results_df['score'].unique()
# Out:
# array([1, 3, 2, 0])

# %%
results_df.groupby("query_id")['passage_id'].count().describe()
# Out:
# count    50.000000
# mean     32.160000
# std       6.557003
# min      18.000000
# 25%      28.000000
# 50%      32.000000
# 75%      35.750000
# max      47.000000
# Name: passage_id, dtype: float64

# %%
results_df.to_csv("tests/evaluation_05_retrievers_000_009_sampled_50_queries_gpt-4-1106-preview_20231215.tsv", sep='\t', index=False)
