# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
first_df = pd.read_csv("tests/evaluation_08_retrievers_000_009_sampled_50_queries_gpt-4-1106-preview_20231227.tsv", sep="\t")

# %%
second_df = pd.read_csv("tests/evaluation_bm25_massiveweb_1M_000_009_sampled_50_queries_gpt-4-1106-preview_20240102.tsv", sep="\t")

# %%
first_df.groupby("query").count()
# Out:
#                                                     query_id  passage_id  mT5  \
# query
# Como configurar uma linguagem do teclado window...        43          43   43
# Como deixar a internet rápida?                            60          60   60
# Como o Brasil reagiu a epidemia de AIDS no fim ...        45          45   45
# Como obter o visto EB-5?                                  46          46   46
# Como podemos classificar o relevo brasileiro?             49          49   49
# Como transformar uma cidade pacata em um polo t...        66          66   66
# Cuidados ao usar materiais perfurocortantes               50          50   50
# Delirio versus alucinação                                 65          65   65
# Existem vantagens ao definir uma moeda única?             59          59   59
# Fatores de risco para cancer de pele                      42          42   42
# Motivos para a saída de Jorge Jesus da Benfica?           39          39   39
# No que se difere o civismo da cidadania?                  54          54   54
# O que pode deixar a internet lenta?                       42          42   42
# O que são os celulares "mid-range"?                       67          67   67
# O que é a associação em série de um capacitor?            29          29   29
# Onde está localizada a Praça XV de Novembro?              57          57   57
# Opções de Seguro da Essor Seguros                         51          51   51
# Por que a legislação de um país é tão importante?         67          67   67
# Por que dividir um país em estados?                       64          64   64
# Por que os anos de 80 são considerados a década...        44          44   44
# Por que os países Guiana e Suriname não são fil...        62          62   62
# Quais as causas para lábios inflamados em crian...        56          56   56
# Quais as etapas de distribuição da coca-cola?             48          48   48
# Quais as formas de pagamento disponível no PagT...        43          43   43
# Quais as origens de pessoas com olhos verdes?             46          46   46
# Quais atitudes podem prejudicar a saúde mental?           52          52   52
# Quais foram os principais artistas do Impressio...        49          49   49
# Quais os sinonimos de eficiência relacionado a ...        53          53   53
# Quais os tipos de denominação (DO) que os vinho...        56          56   56
# Quais partidos já ocuparam o cargo da presidênc...        63          63   63
# Quais são os biomas do Brasil?                            49          49   49
# Quais são os melhores parques nacionais de Port...        51          51   51
# Quais são os principais intérpretes da música b...        65          65   65
# Qual a causa de pessoas com olho de cada cor?             62          62   62
# Qual a maior característica da fauna brasileira?          54          54   54
# Qual a maior torcida de futebol do Brasil?                34          34   34
# Qual a melhor cidade para ficar no Jalapão?               40          40   40
# Qual foi a importância da usina de Volta Redond...        53          53   53
# Qual o critério para classificação para a Copa ...        54          54   54
# Qual o nosso atual sistema de governo?                    62          62   62
# Qual o sistema de governo da África do Sul?               47          47   47
# Qual o uso dos códigos SWIFT?                             42          42   42
# Qual é a principal cidade do basquete brasileiro?         49          49   49
# Quando foi criada a consolidação das leis traba...        44          44   44
# Quando se realizou o plebiscito popular para de...        42          42   42
# Quando é o dia Mundial da Alimentação?                    38          38   38
# Quantas placas são formadas pelos materiais con...        70          70   70
# quais os critérios de definição dos monumentos ...        48          48   48
# quais países europeus seguem o regime monarquista?        54          54   54
# É possível conhecer o Pico da Bandeira com cria...        64          64   64
#
#                                                     splade  colbertx  bm25_e5  \
# query
# Como configurar uma linguagem do teclado window...      43        43       43
# Como deixar a internet rápida?                          60        60       60
# Como o Brasil reagiu a epidemia de AIDS no fim ...      45        45       45
# Como obter o visto EB-5?                                46        46       46
# Como podemos classificar o relevo brasileiro?           49        49       49
# Como transformar uma cidade pacata em um polo t...      66        66       66
# Cuidados ao usar materiais perfurocortantes             50        50       50
# Delirio versus alucinação                               65        65       65
# Existem vantagens ao definir uma moeda única?           59        59       59
# Fatores de risco para cancer de pele                    42        42       42
# Motivos para a saída de Jorge Jesus da Benfica?         39        39       39
# No que se difere o civismo da cidadania?                54        54       54
# O que pode deixar a internet lenta?                     42        42       42
# O que são os celulares "mid-range"?                     67        67       67
# O que é a associação em série de um capacitor?          29        29       29
# Onde está localizada a Praça XV de Novembro?            57        57       57
# Opções de Seguro da Essor Seguros                       51        51       51
# Por que a legislação de um país é tão importante?       67        67       67
# Por que dividir um país em estados?                     64        64       64
# Por que os anos de 80 são considerados a década...      44        44       44
# Por que os países Guiana e Suriname não são fil...      62        62       62
# Quais as causas para lábios inflamados em crian...      56        56       56
# Quais as etapas de distribuição da coca-cola?           48        48       48
# Quais as formas de pagamento disponível no PagT...      43        43       43
# Quais as origens de pessoas com olhos verdes?           46        46       46
# Quais atitudes podem prejudicar a saúde mental?         52        52       52
# Quais foram os principais artistas do Impressio...      49        49       49
# Quais os sinonimos de eficiência relacionado a ...      53        53       53
# Quais os tipos de denominação (DO) que os vinho...      56        56       56
# Quais partidos já ocuparam o cargo da presidênc...      63        63       63
# Quais são os biomas do Brasil?                          49        49       49
# Quais são os melhores parques nacionais de Port...      51        51       51
# Quais são os principais intérpretes da música b...      65        65       65
# Qual a causa de pessoas com olho de cada cor?           62        62       62
# Qual a maior característica da fauna brasileira?        54        54       54
# Qual a maior torcida de futebol do Brasil?              34        34       34
# Qual a melhor cidade para ficar no Jalapão?             40        40       40
# Qual foi a importância da usina de Volta Redond...      53        53       53
# Qual o critério para classificação para a Copa ...      54        54       54
# Qual o nosso atual sistema de governo?                  62        62       62
# Qual o sistema de governo da África do Sul?             47        47       47
# Qual o uso dos códigos SWIFT?                           42        42       42
# Qual é a principal cidade do basquete brasileiro?       49        49       49
# Quando foi criada a consolidação das leis traba...      44        44       44
# Quando se realizou o plebiscito popular para de...      42        42       42
# Quando é o dia Mundial da Alimentação?                  38        38       38
# Quantas placas são formadas pelos materiais con...      70        70       70
# quais os critérios de definição dos monumentos ...      48        48       48
# quais países europeus seguem o regime monarquista?      54        54       54
# É possível conhecer o Pico da Bandeira com cria...      64        64       64
#
#                                                     bm25  e5  e5_base  \
# query
# Como configurar uma linguagem do teclado window...    43  43       43
# Como deixar a internet rápida?                        60  60       60
# Como o Brasil reagiu a epidemia de AIDS no fim ...    45  45       45
# Como obter o visto EB-5?                              46  46       46
# Como podemos classificar o relevo brasileiro?         49  49       49
# Como transformar uma cidade pacata em um polo t...    66  66       66
# Cuidados ao usar materiais perfurocortantes           50  50       50
# Delirio versus alucinação                             65  65       65
# Existem vantagens ao definir uma moeda única?         59  59       59
# Fatores de risco para cancer de pele                  42  42       42
# Motivos para a saída de Jorge Jesus da Benfica?       39  39       39
# No que se difere o civismo da cidadania?              54  54       54
# O que pode deixar a internet lenta?                   42  42       42
# O que são os celulares "mid-range"?                   67  67       67
# O que é a associação em série de um capacitor?        29  29       29
# Onde está localizada a Praça XV de Novembro?          57  57       57
# Opções de Seguro da Essor Seguros                     51  51       51
# Por que a legislação de um país é tão importante?     67  67       67
# Por que dividir um país em estados?                   64  64       64
# Por que os anos de 80 são considerados a década...    44  44       44
# Por que os países Guiana e Suriname não são fil...    62  62       62
# Quais as causas para lábios inflamados em crian...    56  56       56
# Quais as etapas de distribuição da coca-cola?         48  48       48
# Quais as formas de pagamento disponível no PagT...    43  43       43
# Quais as origens de pessoas com olhos verdes?         46  46       46
# Quais atitudes podem prejudicar a saúde mental?       52  52       52
# Quais foram os principais artistas do Impressio...    49  49       49
# Quais os sinonimos de eficiência relacionado a ...    53  53       53
# Quais os tipos de denominação (DO) que os vinho...    56  56       56
# Quais partidos já ocuparam o cargo da presidênc...    63  63       63
# Quais são os biomas do Brasil?                        49  49       49
# Quais são os melhores parques nacionais de Port...    51  51       51
# Quais são os principais intérpretes da música b...    65  65       65
# Qual a causa de pessoas com olho de cada cor?         62  62       62
# Qual a maior característica da fauna brasileira?      54  54       54
# Qual a maior torcida de futebol do Brasil?            34  34       34
# Qual a melhor cidade para ficar no Jalapão?           40  40       40
# Qual foi a importância da usina de Volta Redond...    53  53       53
# Qual o critério para classificação para a Copa ...    54  54       54
# Qual o nosso atual sistema de governo?                62  62       62
# Qual o sistema de governo da África do Sul?           47  47       47
# Qual o uso dos códigos SWIFT?                         42  42       42
# Qual é a principal cidade do basquete brasileiro?     49  49       49
# Quando foi criada a consolidação das leis traba...    44  44       44
# Quando se realizou o plebiscito popular para de...    42  42       42
# Quando é o dia Mundial da Alimentação?                38  38       38
# Quantas placas são formadas pelos materiais con...    70  70       70
# quais os critérios de definição dos monumentos ...    48  48       48
# quais países europeus seguem o regime monarquista?    54  54       54
# É possível conhecer o Pico da Bandeira com cria...    64  64       64
#
#                                                     bm25_1M  passage  score  \
# query
# Como configurar uma linguagem do teclado window...       43       43     43
# Como deixar a internet rápida?                           60       60     60
# Como o Brasil reagiu a epidemia de AIDS no fim ...       45       45     45
# Como obter o visto EB-5?                                 46       46     46
# Como podemos classificar o relevo brasileiro?            49       49     49
# Como transformar uma cidade pacata em um polo t...       66       66     66
# Cuidados ao usar materiais perfurocortantes              50       50     50
# Delirio versus alucinação                                65       65     65
# Existem vantagens ao definir uma moeda única?            59       59     59
# Fatores de risco para cancer de pele                     42       42     42
# Motivos para a saída de Jorge Jesus da Benfica?          39       39     39
# No que se difere o civismo da cidadania?                 54       54     54
# O que pode deixar a internet lenta?                      42       42     42
# O que são os celulares "mid-range"?                      67       67     67
# O que é a associação em série de um capacitor?           29       29     29
# Onde está localizada a Praça XV de Novembro?             57       57     57
# Opções de Seguro da Essor Seguros                        51       51     51
# Por que a legislação de um país é tão importante?        67       67     67
# Por que dividir um país em estados?                      64       64     64
# Por que os anos de 80 são considerados a década...       44       44     44
# Por que os países Guiana e Suriname não são fil...       62       62     62
# Quais as causas para lábios inflamados em crian...       56       56     56
# Quais as etapas de distribuição da coca-cola?            48       48     48
# Quais as formas de pagamento disponível no PagT...       43       43     43
# Quais as origens de pessoas com olhos verdes?            46       46     46
# Quais atitudes podem prejudicar a saúde mental?          52       52     52
# Quais foram os principais artistas do Impressio...       49       49     49
# Quais os sinonimos de eficiência relacionado a ...       53       53     53
# Quais os tipos de denominação (DO) que os vinho...       56       56     56
# Quais partidos já ocuparam o cargo da presidênc...       63       63     63
# Quais são os biomas do Brasil?                           49       49     49
# Quais são os melhores parques nacionais de Port...       51       51     51
# Quais são os principais intérpretes da música b...       65       65     65
# Qual a causa de pessoas com olho de cada cor?            62       62     62
# Qual a maior característica da fauna brasileira?         54       54     54
# Qual a maior torcida de futebol do Brasil?               34       34     34
# Qual a melhor cidade para ficar no Jalapão?              40       40     40
# Qual foi a importância da usina de Volta Redond...       53       53     53
# Qual o critério para classificação para a Copa ...       54       54     54
# Qual o nosso atual sistema de governo?                   62       62     62
# Qual o sistema de governo da África do Sul?              47       47     47
# Qual o uso dos códigos SWIFT?                            42       42     42
# Qual é a principal cidade do basquete brasileiro?        49       49     49
# Quando foi criada a consolidação das leis traba...       44       44     44
# Quando se realizou o plebiscito popular para de...       42       42     42
# Quando é o dia Mundial da Alimentação?                   38       38     38
# Quantas placas são formadas pelos materiais con...       70       70     70
# quais os critérios de definição dos monumentos ...       48       48     48
# quais países europeus seguem o regime monarquista?       54       54     54
# É possível conhecer o Pico da Bandeira com cria...       64       64     64
#
#                                                     reasoning  usage  cost  \
# query
# Como configurar uma linguagem do teclado window...         43     43    43
# Como deixar a internet rápida?                             60     60    60
# Como o Brasil reagiu a epidemia de AIDS no fim ...         45     45    45
# Como obter o visto EB-5?                                   46     46    46
# Como podemos classificar o relevo brasileiro?              49     49    49
# Como transformar uma cidade pacata em um polo t...         66     66    66
# Cuidados ao usar materiais perfurocortantes                50     50    50
# Delirio versus alucinação                                  65     65    65
# Existem vantagens ao definir uma moeda única?              59     59    59
# Fatores de risco para cancer de pele                       42     42    42
# Motivos para a saída de Jorge Jesus da Benfica?            39     39    39
# No que se difere o civismo da cidadania?                   54     54    54
# O que pode deixar a internet lenta?                        42     42    42
# O que são os celulares "mid-range"?                        67     67    67
# O que é a associação em série de um capacitor?             29     29    29
# Onde está localizada a Praça XV de Novembro?               57     57    57
# Opções de Seguro da Essor Seguros                          51     51    51
# Por que a legislação de um país é tão importante?          67     67    67
# Por que dividir um país em estados?                        64     64    64
# Por que os anos de 80 são considerados a década...         44     44    44
# Por que os países Guiana e Suriname não são fil...         62     62    62
# Quais as causas para lábios inflamados em crian...         56     56    56
# Quais as etapas de distribuição da coca-cola?              48     48    48
# Quais as formas de pagamento disponível no PagT...         43     43    43
# Quais as origens de pessoas com olhos verdes?              46     46    46
# Quais atitudes podem prejudicar a saúde mental?            52     52    52
# Quais foram os principais artistas do Impressio...         49     49    49
# Quais os sinonimos de eficiência relacionado a ...         53     53    53
# Quais os tipos de denominação (DO) que os vinho...         56     56    56
# Quais partidos já ocuparam o cargo da presidênc...         63     63    63
# Quais são os biomas do Brasil?                             49     49    49
# Quais são os melhores parques nacionais de Port...         51     51    51
# Quais são os principais intérpretes da música b...         65     65    65
# Qual a causa de pessoas com olho de cada cor?              62     62    62
# Qual a maior característica da fauna brasileira?           54     54    54
# Qual a maior torcida de futebol do Brasil?                 34     34    34
# Qual a melhor cidade para ficar no Jalapão?                40     40    40
# Qual foi a importância da usina de Volta Redond...         53     53    53
# Qual o critério para classificação para a Copa ...         54     54    54
# Qual o nosso atual sistema de governo?                     62     62    62
# Qual o sistema de governo da África do Sul?                47     47    47
# Qual o uso dos códigos SWIFT?                              42     42    42
# Qual é a principal cidade do basquete brasileiro?          49     49    49
# Quando foi criada a consolidação das leis traba...         44     44    44
# Quando se realizou o plebiscito popular para de...         42     42    42
# Quando é o dia Mundial da Alimentação?                     38     38    38
# Quantas placas são formadas pelos materiais con...         70     70    70
# quais os critérios de definição dos monumentos ...         48     48    48
# quais países europeus seguem o regime monarquista?         54     54    54
# É possível conhecer o Pico da Bandeira com cria...         64     64    64
#
#                                                     duration  saved_cost
# query
# Como configurar uma linguagem do teclado window...        43          43
# Como deixar a internet rápida?                            60          60
# Como o Brasil reagiu a epidemia de AIDS no fim ...        45          45
# Como obter o visto EB-5?                                  46          46
# Como podemos classificar o relevo brasileiro?             49          49
# Como transformar uma cidade pacata em um polo t...        66          66
# Cuidados ao usar materiais perfurocortantes               50          50
# Delirio versus alucinação                                 65          65
# Existem vantagens ao definir uma moeda única?             59          59
# Fatores de risco para cancer de pele                      42          42
# Motivos para a saída de Jorge Jesus da Benfica?           39          39
# No que se difere o civismo da cidadania?                  54          54
# O que pode deixar a internet lenta?                       42          42
# O que são os celulares "mid-range"?                       67          67
# O que é a associação em série de um capacitor?            29          29
# Onde está localizada a Praça XV de Novembro?              57          57
# Opções de Seguro da Essor Seguros                         51          51
# Por que a legislação de um país é tão importante?         67          67
# Por que dividir um país em estados?                       64          64
# Por que os anos de 80 são considerados a década...        44          44
# Por que os países Guiana e Suriname não são fil...        62          62
# Quais as causas para lábios inflamados em crian...        56          56
# Quais as etapas de distribuição da coca-cola?             48          48
# Quais as formas de pagamento disponível no PagT...        43          43
# Quais as origens de pessoas com olhos verdes?             46          46
# Quais atitudes podem prejudicar a saúde mental?           52          52
# Quais foram os principais artistas do Impressio...        49          49
# Quais os sinonimos de eficiência relacionado a ...        53          53
# Quais os tipos de denominação (DO) que os vinho...        56          56
# Quais partidos já ocuparam o cargo da presidênc...        63          63
# Quais são os biomas do Brasil?                            49          49
# Quais são os melhores parques nacionais de Port...        51          51
# Quais são os principais intérpretes da música b...        65          65
# Qual a causa de pessoas com olho de cada cor?             62          62
# Qual a maior característica da fauna brasileira?          54          54
# Qual a maior torcida de futebol do Brasil?                34          34
# Qual a melhor cidade para ficar no Jalapão?               40          40
# Qual foi a importância da usina de Volta Redond...        53          53
# Qual o critério para classificação para a Copa ...        54          54
# Qual o nosso atual sistema de governo?                    62          62
# Qual o sistema de governo da África do Sul?               47          47
# Qual o uso dos códigos SWIFT?                             42          42
# Qual é a principal cidade do basquete brasileiro?         49          49
# Quando foi criada a consolidação das leis traba...        44          44
# Quando se realizou o plebiscito popular para de...        42          42
# Quando é o dia Mundial da Alimentação?                    38          38
# Quantas placas são formadas pelos materiais con...        70          70
# quais os critérios de definição dos monumentos ...        48          48
# quais países europeus seguem o regime monarquista?        54          54
# É possível conhecer o Pico da Bandeira com cria...        64          64

# %%
second_df.groupby("query").count()
# Out:
#                                                     query_id  Q0  colbertx_id  \
# query
# Como configurar uma linguagem do teclado window...        10  10           10
# Como deixar a internet rápida?                            10  10           10
# Como o Brasil reagiu a epidemia de AIDS no fim ...        10  10           10
# Como obter o visto EB-5?                                  10  10           10
# Como podemos classificar o relevo brasileiro?             10  10           10
# Como transformar uma cidade pacata em um polo t...        10  10           10
# Cuidados ao usar materiais perfurocortantes               10  10           10
# Delirio versus alucinação                                 10  10           10
# Existem vantagens ao definir uma moeda única?             10  10           10
# Fatores de risco para cancer de pele                      10  10           10
# Motivos para a saída de Jorge Jesus da Benfica?           10  10           10
# No que se difere o civismo da cidadania?                  10  10           10
# O que pode deixar a internet lenta?                       10  10           10
# O que são os celulares "mid-range"?                       10  10           10
# O que é a associação em série de um capacitor?            10  10           10
# Onde está localizada a Praça XV de Novembro?              10  10           10
# Opções de Seguro da Essor Seguros                         10  10           10
# Por que a legislação de um país é tão importante?         10  10           10
# Por que dividir um país em estados?                       10  10           10
# Por que os anos de 80 são considerados a década...        10  10           10
# Por que os países Guiana e Suriname não são fil...        10  10           10
# Quais as causas para lábios inflamados em crian...        10  10           10
# Quais as etapas de distribuição da coca-cola?             10  10           10
# Quais as formas de pagamento disponível no PagT...        10  10           10
# Quais as origens de pessoas com olhos verdes?             10  10           10
# Quais atitudes podem prejudicar a saúde mental?           10  10           10
# Quais foram os principais artistas do Impressio...        10  10           10
# Quais os sinonimos de eficiência relacionado a ...        10  10           10
# Quais os tipos de denominação (DO) que os vinho...        10  10           10
# Quais partidos já ocuparam o cargo da presidênc...        10  10           10
# Quais são os biomas do Brasil?                            10  10           10
# Quais são os melhores parques nacionais de Port...        10  10           10
# Quais são os principais intérpretes da música b...        10  10           10
# Qual a causa de pessoas com olho de cada cor?             10  10           10
# Qual a maior característica da fauna brasileira?          10  10           10
# Qual a maior torcida de futebol do Brasil?                10  10           10
# Qual a melhor cidade para ficar no Jalapão?               10  10           10
# Qual foi a importância da usina de Volta Redond...        10  10           10
# Qual o critério para classificação para a Copa ...        10  10           10
# Qual o nosso atual sistema de governo?                    10  10           10
# Qual o sistema de governo da África do Sul?               10  10           10
# Qual o uso dos códigos SWIFT?                             10  10           10
# Qual é a principal cidade do basquete brasileiro?         10  10           10
# Quando foi criada a consolidação das leis traba...        10  10           10
# Quando se realizou o plebiscito popular para de...        10  10           10
# Quando é o dia Mundial da Alimentação?                    10  10           10
# Quantas placas são formadas pelos materiais con...        10  10           10
# quais os critérios de definição dos monumentos ...        10  10           10
# quais países europeus seguem o regime monarquista?        10  10           10
# É possível conhecer o Pico da Bandeira com cria...        10  10           10
#
#                                                     position  score  comment  \
# query
# Como configurar uma linguagem do teclado window...        10     10       10
# Como deixar a internet rápida?                            10     10       10
# Como o Brasil reagiu a epidemia de AIDS no fim ...        10     10       10
# Como obter o visto EB-5?                                  10     10       10
# Como podemos classificar o relevo brasileiro?             10     10       10
# Como transformar uma cidade pacata em um polo t...        10     10       10
# Cuidados ao usar materiais perfurocortantes               10     10       10
# Delirio versus alucinação                                 10     10       10
# Existem vantagens ao definir uma moeda única?             10     10       10
# Fatores de risco para cancer de pele                      10     10       10
# Motivos para a saída de Jorge Jesus da Benfica?           10     10       10
# No que se difere o civismo da cidadania?                  10     10       10
# O que pode deixar a internet lenta?                       10     10       10
# O que são os celulares "mid-range"?                       10     10       10
# O que é a associação em série de um capacitor?            10     10       10
# Onde está localizada a Praça XV de Novembro?              10     10       10
# Opções de Seguro da Essor Seguros                         10     10       10
# Por que a legislação de um país é tão importante?         10     10       10
# Por que dividir um país em estados?                       10     10       10
# Por que os anos de 80 são considerados a década...        10     10       10
# Por que os países Guiana e Suriname não são fil...        10     10       10
# Quais as causas para lábios inflamados em crian...        10     10       10
# Quais as etapas de distribuição da coca-cola?             10     10       10
# Quais as formas de pagamento disponível no PagT...        10     10       10
# Quais as origens de pessoas com olhos verdes?             10     10       10
# Quais atitudes podem prejudicar a saúde mental?           10     10       10
# Quais foram os principais artistas do Impressio...        10     10       10
# Quais os sinonimos de eficiência relacionado a ...        10     10       10
# Quais os tipos de denominação (DO) que os vinho...        10     10       10
# Quais partidos já ocuparam o cargo da presidênc...        10     10       10
# Quais são os biomas do Brasil?                            10     10       10
# Quais são os melhores parques nacionais de Port...        10     10       10
# Quais são os principais intérpretes da música b...        10     10       10
# Qual a causa de pessoas com olho de cada cor?             10     10       10
# Qual a maior característica da fauna brasileira?          10     10       10
# Qual a maior torcida de futebol do Brasil?                10     10       10
# Qual a melhor cidade para ficar no Jalapão?               10     10       10
# Qual foi a importância da usina de Volta Redond...        10     10       10
# Qual o critério para classificação para a Copa ...        10     10       10
# Qual o nosso atual sistema de governo?                    10     10       10
# Qual o sistema de governo da África do Sul?               10     10       10
# Qual o uso dos códigos SWIFT?                             10     10       10
# Qual é a principal cidade do basquete brasileiro?         10     10       10
# Quando foi criada a consolidação das leis traba...        10     10       10
# Quando se realizou o plebiscito popular para de...        10     10       10
# Quando é o dia Mundial da Alimentação?                    10     10       10
# Quantas placas são formadas pelos materiais con...        10     10       10
# quais os critérios de definição dos monumentos ...        10     10       10
# quais países europeus seguem o regime monarquista?        10     10       10
# É possível conhecer o Pico da Bandeira com cria...        10     10       10
#
#                                                     passage_id  passage  \
# query
# Como configurar uma linguagem do teclado window...          10       10
# Como deixar a internet rápida?                              10       10
# Como o Brasil reagiu a epidemia de AIDS no fim ...          10       10
# Como obter o visto EB-5?                                    10       10
# Como podemos classificar o relevo brasileiro?               10       10
# Como transformar uma cidade pacata em um polo t...          10       10
# Cuidados ao usar materiais perfurocortantes                 10       10
# Delirio versus alucinação                                   10       10
# Existem vantagens ao definir uma moeda única?               10       10
# Fatores de risco para cancer de pele                        10       10
# Motivos para a saída de Jorge Jesus da Benfica?             10       10
# No que se difere o civismo da cidadania?                    10       10
# O que pode deixar a internet lenta?                         10       10
# O que são os celulares "mid-range"?                         10       10
# O que é a associação em série de um capacitor?              10       10
# Onde está localizada a Praça XV de Novembro?                10       10
# Opções de Seguro da Essor Seguros                           10       10
# Por que a legislação de um país é tão importante?           10       10
# Por que dividir um país em estados?                         10       10
# Por que os anos de 80 são considerados a década...          10       10
# Por que os países Guiana e Suriname não são fil...          10       10
# Quais as causas para lábios inflamados em crian...          10       10
# Quais as etapas de distribuição da coca-cola?               10       10
# Quais as formas de pagamento disponível no PagT...          10       10
# Quais as origens de pessoas com olhos verdes?               10       10
# Quais atitudes podem prejudicar a saúde mental?             10       10
# Quais foram os principais artistas do Impressio...          10       10
# Quais os sinonimos de eficiência relacionado a ...          10       10
# Quais os tipos de denominação (DO) que os vinho...          10       10
# Quais partidos já ocuparam o cargo da presidênc...          10       10
# Quais são os biomas do Brasil?                              10       10
# Quais são os melhores parques nacionais de Port...          10       10
# Quais são os principais intérpretes da música b...          10       10
# Qual a causa de pessoas com olho de cada cor?               10       10
# Qual a maior característica da fauna brasileira?            10       10
# Qual a maior torcida de futebol do Brasil?                  10       10
# Qual a melhor cidade para ficar no Jalapão?                 10       10
# Qual foi a importância da usina de Volta Redond...          10       10
# Qual o critério para classificação para a Copa ...          10       10
# Qual o nosso atual sistema de governo?                      10       10
# Qual o sistema de governo da África do Sul?                 10       10
# Qual o uso dos códigos SWIFT?                               10       10
# Qual é a principal cidade do basquete brasileiro?           10       10
# Quando foi criada a consolidação das leis traba...          10       10
# Quando se realizou o plebiscito popular para de...          10       10
# Quando é o dia Mundial da Alimentação?                      10       10
# Quantas placas são formadas pelos materiais con...          10       10
# quais os critérios de definição dos monumentos ...          10       10
# quais países europeus seguem o regime monarquista?          10       10
# É possível conhecer o Pico da Bandeira com cria...          10       10
#
#                                                     score.1  reasoning  usage  \
# query
# Como configurar uma linguagem do teclado window...       10         10     10
# Como deixar a internet rápida?                           10         10     10
# Como o Brasil reagiu a epidemia de AIDS no fim ...       10         10     10
# Como obter o visto EB-5?                                 10         10     10
# Como podemos classificar o relevo brasileiro?            10         10     10
# Como transformar uma cidade pacata em um polo t...       10         10     10
# Cuidados ao usar materiais perfurocortantes              10         10     10
# Delirio versus alucinação                                10         10     10
# Existem vantagens ao definir uma moeda única?            10         10     10
# Fatores de risco para cancer de pele                     10         10     10
# Motivos para a saída de Jorge Jesus da Benfica?          10         10     10
# No que se difere o civismo da cidadania?                 10         10     10
# O que pode deixar a internet lenta?                      10         10     10
# O que são os celulares "mid-range"?                      10         10     10
# O que é a associação em série de um capacitor?           10         10     10
# Onde está localizada a Praça XV de Novembro?             10         10     10
# Opções de Seguro da Essor Seguros                        10         10     10
# Por que a legislação de um país é tão importante?        10         10     10
# Por que dividir um país em estados?                      10         10     10
# Por que os anos de 80 são considerados a década...       10         10     10
# Por que os países Guiana e Suriname não são fil...       10         10     10
# Quais as causas para lábios inflamados em crian...       10         10     10
# Quais as etapas de distribuição da coca-cola?            10         10     10
# Quais as formas de pagamento disponível no PagT...       10         10     10
# Quais as origens de pessoas com olhos verdes?            10         10     10
# Quais atitudes podem prejudicar a saúde mental?          10         10     10
# Quais foram os principais artistas do Impressio...       10         10     10
# Quais os sinonimos de eficiência relacionado a ...       10         10     10
# Quais os tipos de denominação (DO) que os vinho...       10         10     10
# Quais partidos já ocuparam o cargo da presidênc...       10         10     10
# Quais são os biomas do Brasil?                           10         10     10
# Quais são os melhores parques nacionais de Port...       10         10     10
# Quais são os principais intérpretes da música b...       10         10     10
# Qual a causa de pessoas com olho de cada cor?            10         10     10
# Qual a maior característica da fauna brasileira?         10         10     10
# Qual a maior torcida de futebol do Brasil?               10         10     10
# Qual a melhor cidade para ficar no Jalapão?              10         10     10
# Qual foi a importância da usina de Volta Redond...       10         10     10
# Qual o critério para classificação para a Copa ...       10         10     10
# Qual o nosso atual sistema de governo?                   10         10     10
# Qual o sistema de governo da África do Sul?              10         10     10
# Qual o uso dos códigos SWIFT?                            10         10     10
# Qual é a principal cidade do basquete brasileiro?        10         10     10
# Quando foi criada a consolidação das leis traba...       10         10     10
# Quando se realizou o plebiscito popular para de...       10         10     10
# Quando é o dia Mundial da Alimentação?                   10         10     10
# Quantas placas são formadas pelos materiais con...       10         10     10
# quais os critérios de definição dos monumentos ...       10         10     10
# quais países europeus seguem o regime monarquista?       10         10     10
# É possível conhecer o Pico da Bandeira com cria...       10         10     10
#
#                                                     cost  duration  saved_cost
# query
# Como configurar uma linguagem do teclado window...    10        10          10
# Como deixar a internet rápida?                        10        10          10
# Como o Brasil reagiu a epidemia de AIDS no fim ...    10        10          10
# Como obter o visto EB-5?                              10        10          10
# Como podemos classificar o relevo brasileiro?         10        10          10
# Como transformar uma cidade pacata em um polo t...    10        10          10
# Cuidados ao usar materiais perfurocortantes           10        10          10
# Delirio versus alucinação                             10        10          10
# Existem vantagens ao definir uma moeda única?         10        10          10
# Fatores de risco para cancer de pele                  10        10          10
# Motivos para a saída de Jorge Jesus da Benfica?       10        10          10
# No que se difere o civismo da cidadania?              10        10          10
# O que pode deixar a internet lenta?                   10        10          10
# O que são os celulares "mid-range"?                   10        10          10
# O que é a associação em série de um capacitor?        10        10          10
# Onde está localizada a Praça XV de Novembro?          10        10          10
# Opções de Seguro da Essor Seguros                     10        10          10
# Por que a legislação de um país é tão importante?     10        10          10
# Por que dividir um país em estados?                   10        10          10
# Por que os anos de 80 são considerados a década...    10        10          10
# Por que os países Guiana e Suriname não são fil...    10        10          10
# Quais as causas para lábios inflamados em crian...    10        10          10
# Quais as etapas de distribuição da coca-cola?         10        10          10
# Quais as formas de pagamento disponível no PagT...    10        10          10
# Quais as origens de pessoas com olhos verdes?         10        10          10
# Quais atitudes podem prejudicar a saúde mental?       10        10          10
# Quais foram os principais artistas do Impressio...    10        10          10
# Quais os sinonimos de eficiência relacionado a ...    10        10          10
# Quais os tipos de denominação (DO) que os vinho...    10        10          10
# Quais partidos já ocuparam o cargo da presidênc...    10        10          10
# Quais são os biomas do Brasil?                        10        10          10
# Quais são os melhores parques nacionais de Port...    10        10          10
# Quais são os principais intérpretes da música b...    10        10          10
# Qual a causa de pessoas com olho de cada cor?         10        10          10
# Qual a maior característica da fauna brasileira?      10        10          10
# Qual a maior torcida de futebol do Brasil?            10        10          10
# Qual a melhor cidade para ficar no Jalapão?           10        10          10
# Qual foi a importância da usina de Volta Redond...    10        10          10
# Qual o critério para classificação para a Copa ...    10        10          10
# Qual o nosso atual sistema de governo?                10        10          10
# Qual o sistema de governo da África do Sul?           10        10          10
# Qual o uso dos códigos SWIFT?                         10        10          10
# Qual é a principal cidade do basquete brasileiro?     10        10          10
# Quando foi criada a consolidação das leis traba...    10        10          10
# Quando se realizou o plebiscito popular para de...    10        10          10
# Quando é o dia Mundial da Alimentação?                10        10          10
# Quantas placas são formadas pelos materiais con...    10        10          10
# quais os critérios de definição dos monumentos ...    10        10          10
# quais países europeus seguem o regime monarquista?    10        10          10
# É possível conhecer o Pico da Bandeira com cria...    10        10          10

# %%
first_df.head()
# Out:
#    query_id                                             query  \
# 0         1  Qual a maior característica da fauna brasileira?
# 1         1  Qual a maior característica da fauna brasileira?
# 2         1  Qual a maior característica da fauna brasileira?
# 3         1  Qual a maior característica da fauna brasileira?
# 4         1  Qual a maior característica da fauna brasileira?
#
#                      passage_id    mT5  splade  colbertx  bm25_e5   bm25  \
# 0   clueweb22-pt0000-82-13187_0  False   False      True    False  False
# 1   clueweb22-pt0000-59-04599_2  False   False      True    False  False
# 2  clueweb22-pt0000-64-06285_39   True    True     False    False  False
# 3   clueweb22-pt0000-77-06884_1  False    True      True    False  False
# 4   clueweb22-pt0000-78-09747_0   True   False     False    False   True
#
#       e5  e5_base  bm25_1M                                            passage  \
# 0  False    False    False  Mamíferos do Brasil - Zoologia | Museu Naciona...
# 1  False    False    False  Segundo uma lista levantada pelo Comitê Brasil...
# 2  False     True    False  A exuberante fauna e flora brasileiras, relata...
# 3  False    False    False  O tamanho do Brasil e a grande variedade de cl...
# 4  False    False    False  Onça-pintada - Escola Kids Qual matéria está p...
#
#    score                                          reasoning  \
# 0      1  A passagem lista vários mamíferos da fauna bra...
# 1      1  A passagem descreve várias espécies de aves en...
# 2      3  A passagem menciona que o Brasil tem a maior b...
# 3      1  A passagem menciona a alta biodiversidade do B...
# 4      1  A passagem menciona que a onça-pintada é um do...
#
#                                                usage  cost  duration  \
# 0  {'prompt_tokens': 765, 'completion_tokens': 75...   0.0  6.693229
# 1  {'prompt_tokens': 860, 'completion_tokens': 82...   0.0  5.163547
# 2  {'prompt_tokens': 840, 'completion_tokens': 46...   0.0  5.185688
# 3  {'prompt_tokens': 812, 'completion_tokens': 81...   0.0  5.882017
# 4  {'prompt_tokens': 805, 'completion_tokens': 96...   0.0  5.774773
#
#    saved_cost
# 0     0.02745
# 1     0.03072
# 2     0.02796
# 3     0.02922
# 4     0.02991

# %%
second_df.head()
# Out:
#    query_id  Q0  colbertx_id  position    score   comment  \
# 0         1  Q0       264425         1  11.6703  Anserini
# 1         1  Q0      3718313         2  10.1476  Anserini
# 2         1  Q0      4178525         3   9.9345  Anserini
# 3         1  Q0      3299432         4   9.9165  Anserini
# 4         1  Q0      2605802         5   9.7855  Anserini
#
#                     passage_id  \
# 0  clueweb22-pt0000-05-02747_0
# 1  clueweb22-pt0000-78-09747_0
# 2  clueweb22-pt0000-87-14633_2
# 3  clueweb22-pt0000-69-05954_7
# 4  clueweb22-pt0000-55-02859_0
#
#                                               query  \
# 0  Qual a maior característica da fauna brasileira?
# 1  Qual a maior característica da fauna brasileira?
# 2  Qual a maior característica da fauna brasileira?
# 3  Qual a maior característica da fauna brasileira?
# 4  Qual a maior característica da fauna brasileira?
#
#                                              passage  score.1  \
# 0  BIOMAS E FITOFISIONOMIAS BRASILEIROS: CARACTER...        1
# 1  Onça-pintada - Escola Kids Qual matéria está p...        1
# 2  - Fauna e Flora A fauna da Amazônia é represen...        1
# 3  Aprenda sobre a Bacia do Tocantins-Araguaia, a...        0
# 4  Fauna e Flora: : entenda o que são e quais as ...        2
#
#                                            reasoning  \
# 0  A passagem não responde diretamente à pergunta...
# 1  A passagem menciona que a onça-pintada é um do...
# 2  A passagem não responde diretamente qual é a m...
# 3  A passagem não fornece informações específicas...
# 4  A passagem não fornece uma resposta direta sob...
#
#                                                usage     cost   duration  \
# 0  {'prompt_tokens': 777, 'completion_tokens': 72...  0.00000   4.661217
# 1  {'prompt_tokens': 805, 'completion_tokens': 96...  0.00000   5.774773
# 2  {'prompt_tokens': 858, 'completion_tokens': 85...  0.00000   6.205193
# 3  {'prompt_tokens': 818, 'completion_tokens': 75...  0.02904   7.655364
# 4  {'prompt_tokens': 801, 'completion_tokens': 99...  0.00000  10.403308
#
#    saved_cost
# 0     0.02763
# 1     0.02991
# 2     0.03084
# 3     0.00000
# 4     0.02997

# %%
second_df.shape
# Out:
# (500, 15)

# %% [markdown]
# ### Merge both results

# %%
results = []

for group_name, group_df in first_df.groupby('query_id'):

    print("\nHandling query_id={}".format(group_name))
    
    query_df = second_df[second_df['query_id'] == group_name]
    query_docs = []
    passages = group_df['passage_id'].to_numpy()
    bm25_1M_passages = query_df['passage_id'].to_numpy()
  
    print("-- Existing passages={}\n-- BM25 only passages={}".format(passages.shape[0],
                                                                     10 - np.intersect1d(passages, bm25_1M_passages).shape[0]))
    
    for i, row in group_df.iterrows():

        # print(row)
        
        query_docs.append({"query_id": group_name,
                           "query": row['query'],
                           "passage_id": row['passage_id'],
                           "mT5": row['mT5'],
                           "splade": row['splade'],
                           "colbertx": row['colbertx'],
                           "bm25_e5": row['bm25_e5'],
                           "bm25": row['bm25'],
                           "e5": row['e5'],
                           "e5_base": row['e5_base'],
                           "bm25_1M": row['bm25_1M'],
                           "bm25_1M_massiveweb": row['passage_id'] in bm25_1M_passages,
                           "passage": row['passage'],
                           "score": row['score'],
                           "reasoning": row['reasoning'],
                           "usage": row['usage'],
                           "cost": row['cost'],
                           "duration": row['duration'],
                           "saved_cost": row['saved_cost']})

    for i, row in query_df.iterrows():
        if row['passage_id'] not in passages:
            query_docs.append({"query_id": group_name,
                               "query": row['query'],
                               "passage_id": row['passage_id'],
                               "mT5": False,
                               "splade": False,
                               "colbertx": False,
                               "bm25_e5": False,
                               "bm25": False,
                               "e5": False,
                               "e5_base": False,
                               "bm25_1M": False,
                               "bm25_1M_massiveweb": True,
                               "passage": row['passage'],
                               "score": row['score.1'],
                               "reasoning": row['reasoning'],
                               "usage": row['usage'],
                               "cost": row['cost'],
                               "duration": row['duration'],
                               "saved_cost": row['saved_cost']})                               

    print("-- Final number of passages={}".format(len(query_docs)))

    results += query_docs
# Out:
# Handling query_id=1
# -- Existing passages=54
# -- BM25 only passages=6
# -- Final number of passages=60
#
# Handling query_id=2
# -- Existing passages=62
# -- BM25 only passages=8
# -- Final number of passages=70
#
# Handling query_id=9
# -- Existing passages=54
# -- BM25 only passages=7
# -- Final number of passages=61
#
# Handling query_id=11
# -- Existing passages=48
# -- BM25 only passages=6
# -- Final number of passages=54
#
# Handling query_id=13
# -- Existing passages=45
# -- BM25 only passages=6
# -- Final number of passages=51
#
# Handling query_id=15
# -- Existing passages=34
# -- BM25 only passages=9
# -- Final number of passages=43
#
# Handling query_id=17
# -- Existing passages=42
# -- BM25 only passages=9
# -- Final number of passages=51
#
# Handling query_id=20
# -- Existing passages=67
# -- BM25 only passages=6
# -- Final number of passages=73
#
# Handling query_id=21
# -- Existing passages=62
# -- BM25 only passages=8
# -- Final number of passages=70
#
# Handling query_id=22
# -- Existing passages=47
# -- BM25 only passages=7
# -- Final number of passages=54
#
# Handling query_id=24
# -- Existing passages=64
# -- BM25 only passages=6
# -- Final number of passages=70
#
# Handling query_id=26
# -- Existing passages=49
# -- BM25 only passages=7
# -- Final number of passages=56
#
# Handling query_id=28
# -- Existing passages=59
# -- BM25 only passages=8
# -- Final number of passages=67
#
# Handling query_id=47
# -- Existing passages=66
# -- BM25 only passages=8
# -- Final number of passages=74
#
# Handling query_id=49
# -- Existing passages=51
# -- BM25 only passages=7
# -- Final number of passages=58
#
# Handling query_id=51
# -- Existing passages=40
# -- BM25 only passages=8
# -- Final number of passages=48
#
# Handling query_id=54
# -- Existing passages=49
# -- BM25 only passages=8
# -- Final number of passages=57
#
# Handling query_id=60
# -- Existing passages=44
# -- BM25 only passages=5
# -- Final number of passages=49
#
# Handling query_id=62
# -- Existing passages=63
# -- BM25 only passages=8
# -- Final number of passages=71
#
# Handling query_id=64
# -- Existing passages=44
# -- BM25 only passages=9
# -- Final number of passages=53
#
# Handling query_id=68
# -- Existing passages=65
# -- BM25 only passages=9
# -- Final number of passages=74
#
# Handling query_id=84
# -- Existing passages=49
# -- BM25 only passages=6
# -- Final number of passages=55
#
# Handling query_id=95
# -- Existing passages=64
# -- BM25 only passages=6
# -- Final number of passages=70
#
# Handling query_id=98
# -- Existing passages=54
# -- BM25 only passages=9
# -- Final number of passages=63
#
# Handling query_id=105
# -- Existing passages=57
# -- BM25 only passages=7
# -- Final number of passages=64
#
# Handling query_id=113
# -- Existing passages=42
# -- BM25 only passages=8
# -- Final number of passages=50
#
# Handling query_id=115
# -- Existing passages=50
# -- BM25 only passages=10
# -- Final number of passages=60
#
# Handling query_id=117
# -- Existing passages=65
# -- BM25 only passages=8
# -- Final number of passages=73
#
# Handling query_id=126
# -- Existing passages=70
# -- BM25 only passages=7
# -- Final number of passages=77
#
# Handling query_id=127
# -- Existing passages=29
# -- BM25 only passages=6
# -- Final number of passages=35
#
# Handling query_id=128
# -- Existing passages=38
# -- BM25 only passages=10
# -- Final number of passages=48
#
# Handling query_id=136
# -- Existing passages=53
# -- BM25 only passages=8
# -- Final number of passages=61
#
# Handling query_id=147
# -- Existing passages=51
# -- BM25 only passages=9
# -- Final number of passages=60
#
# Handling query_id=152
# -- Existing passages=53
# -- BM25 only passages=8
# -- Final number of passages=61
#
# Handling query_id=153
# -- Existing passages=56
# -- BM25 only passages=9
# -- Final number of passages=65
#
# Handling query_id=154
# -- Existing passages=42
# -- BM25 only passages=5
# -- Final number of passages=47
#
# Handling query_id=160
# -- Existing passages=43
# -- BM25 only passages=7
# -- Final number of passages=50
#
# Handling query_id=161
# -- Existing passages=39
# -- BM25 only passages=7
# -- Final number of passages=46
#
# Handling query_id=163
# -- Existing passages=48
# -- BM25 only passages=5
# -- Final number of passages=53
#
# Handling query_id=167
# -- Existing passages=67
# -- BM25 only passages=6
# -- Final number of passages=73
#
# Handling query_id=170
# -- Existing passages=56
# -- BM25 only passages=8
# -- Final number of passages=64
#
# Handling query_id=172
# -- Existing passages=43
# -- BM25 only passages=7
# -- Final number of passages=50
#
# Handling query_id=180
# -- Existing passages=46
# -- BM25 only passages=6
# -- Final number of passages=52
#
# Handling query_id=181
# -- Existing passages=62
# -- BM25 only passages=8
# -- Final number of passages=70
#
# Handling query_id=182
# -- Existing passages=46
# -- BM25 only passages=8
# -- Final number of passages=54
#
# Handling query_id=189
# -- Existing passages=54
# -- BM25 only passages=7
# -- Final number of passages=61
#
# Handling query_id=193
# -- Existing passages=52
# -- BM25 only passages=7
# -- Final number of passages=59
#
# Handling query_id=195
# -- Existing passages=42
# -- BM25 only passages=8
# -- Final number of passages=50
#
# Handling query_id=196
# -- Existing passages=60
# -- BM25 only passages=7
# -- Final number of passages=67
#
# Handling query_id=199
# -- Existing passages=49
# -- BM25 only passages=10
# -- Final number of passages=59

# %%
len(results)
# Out:
# 2961

# %%
results_df = pd.DataFrame(results)

# %%
results_df
# Out:
#       query_id                                              query  \
# 0            1   Qual a maior característica da fauna brasileira?
# 1            1   Qual a maior característica da fauna brasileira?
# 2            1   Qual a maior característica da fauna brasileira?
# 3            1   Qual a maior característica da fauna brasileira?
# 4            1   Qual a maior característica da fauna brasileira?
# ...        ...                                                ...
# 2956       199  Quais foram os principais artistas do Impressi...
# 2957       199  Quais foram os principais artistas do Impressi...
# 2958       199  Quais foram os principais artistas do Impressi...
# 2959       199  Quais foram os principais artistas do Impressi...
# 2960       199  Quais foram os principais artistas do Impressi...
#
#                         passage_id    mT5  splade  colbertx  bm25_e5   bm25  \
# 0      clueweb22-pt0000-82-13187_0  False   False      True    False  False
# 1      clueweb22-pt0000-59-04599_2  False   False      True    False  False
# 2     clueweb22-pt0000-64-06285_39   True    True     False    False  False
# 3      clueweb22-pt0000-77-06884_1  False    True      True    False  False
# 4      clueweb22-pt0000-78-09747_0   True   False     False    False   True
# ...                            ...    ...     ...       ...      ...    ...
# 2956   clueweb22-pt0000-48-17441_2  False   False     False    False  False
# 2957   clueweb22-pt0002-04-01418_0  False   False     False    False  False
# 2958   clueweb22-pt0001-24-17228_0  False   False     False    False  False
# 2959   clueweb22-pt0000-08-07683_2  False   False     False    False  False
# 2960   clueweb22-pt0000-86-08729_0  False   False     False    False  False
#
#          e5  e5_base  bm25_1M  bm25_1M_massiveweb  \
# 0     False    False    False               False
# 1     False    False    False               False
# 2     False     True    False               False
# 3     False    False    False               False
# 4     False    False    False                True
# ...     ...      ...      ...                 ...
# 2956  False    False    False                True
# 2957  False    False    False                True
# 2958  False    False    False                True
# 2959  False    False    False                True
# 2960  False    False    False                True
#
#                                                 passage  score  \
# 0     Mamíferos do Brasil - Zoologia | Museu Naciona...      1
# 1     Segundo uma lista levantada pelo Comitê Brasil...      1
# 2     A exuberante fauna e flora brasileiras, relata...      3
# 3     O tamanho do Brasil e a grande variedade de cl...      1
# 4     Onça-pintada - Escola Kids Qual matéria está p...      1
# ...                                                 ...    ...
# 2956  O IMPRESSIONISMO foi um movimento artístico qu...      2
# 2957  O Impressionismo de Monet | Cultura - Cultura ...      2
# 2958  A cultura da gare - 1534 Palavras | Trabalhosf...      0
# 2959  Severini e o Cubismo Os traços do futurismo ga...      1
# 2960  Eugène Boudin - 560 obras de arte - pintura In...      1
#
#                                               reasoning  \
# 0     A passagem lista vários mamíferos da fauna bra...
# 1     A passagem descreve várias espécies de aves en...
# 2     A passagem menciona que o Brasil tem a maior b...
# 3     A passagem menciona a alta biodiversidade do B...
# 4     A passagem menciona que a onça-pintada é um do...
# ...                                                 ...
# 2956  A passagem menciona o Impressionismo e cita do...
# 2957  A passagem foca especificamente em Claude Mone...
# 2958  A passagem menciona o Impressionismo como um d...
# 2959  A passagem menciona o Impressionismo e fala br...
# 2960  A passagem menciona Eugène Boudin como um prec...
#
#                                                   usage     cost  duration  \
# 0     {'prompt_tokens': 765, 'completion_tokens': 75...  0.00000  6.693229
# 1     {'prompt_tokens': 860, 'completion_tokens': 82...  0.00000  5.163547
# 2     {'prompt_tokens': 840, 'completion_tokens': 46...  0.00000  5.185688
# 3     {'prompt_tokens': 812, 'completion_tokens': 81...  0.00000  5.882017
# 4     {'prompt_tokens': 805, 'completion_tokens': 96...  0.00000  5.774773
# ...                                                 ...      ...       ...
# 2956  {'prompt_tokens': 841, 'completion_tokens': 74...  0.02967  3.569607
# 2957  {'prompt_tokens': 831, 'completion_tokens': 88...  0.03021  6.583927
# 2958  {'prompt_tokens': 886, 'completion_tokens': 62...  0.03030  3.409698
# 2959  {'prompt_tokens': 818, 'completion_tokens': 71...  0.02880  6.635229
# 2960  {'prompt_tokens': 894, 'completion_tokens': 83...  0.03180  4.696065
#
#       saved_cost
# 0        0.02745
# 1        0.03072
# 2        0.02796
# 3        0.02922
# 4        0.02991
# ...          ...
# 2956     0.00000
# 2957     0.00000
# 2958     0.00000
# 2959     0.00000
# 2960     0.00000
#
# [2961 rows x 19 columns]

# %%
results_df['score'].unique()
# Out:
# array([1, 3, 2, 0])

# %%
results_df.groupby("query_id")['passage_id'].count().describe()
# Out:
# count    50.000000
# mean     59.220000
# std       9.607161
# min      35.000000
# 25%      51.250000
# 50%      59.500000
# 75%      67.000000
# max      77.000000
# Name: passage_id, dtype: float64

# %%
results_df.to_csv("tests/evaluation_09_retrievers_000_009_sampled_50_queries_gpt-4-1106-preview_20240103.tsv", sep='\t', index=False)

# %%
results_df.shape
# Out:
# (2961, 19)

# %%
results_df.dropna().shape
# Out:
# (2961, 19)
